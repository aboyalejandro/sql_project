# %%
#Imports

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests

# %% [markdown]
# # Dictionary with top schools

# %%
schools = {   
'4geeks-academy'  : 10492,
'academia-de-codigo'  : 10494,
'actualize'  : 10505,
'altcademy'  : 10517,
'app-academy'  : 10525,
'bloomtech'  : 10854,
'brainstation'  : 10571,
'careerfoundry'  : 10581,
'careerist'  : 11280,
'claim-academy'  : 10589,
'clarusway'  : 11539,
'code-fellows'  : 10614,
'code-institute'  : 10619,
'codesmith'  : 10643,
'codeworks'  : 10650,
'coding-bootcamp-praha'  : 10658,
'coding-dojo'  : 10659,
'coding-temple'  : 10664,
#'correlation-one'  : 11528,
'datacamp'  : 10682,
'dataquest'  : 10683,
'data-science-dojo'  : 10685,
'datascientest'  : 11232,
'designlab'  : 10697,
'devcodecamp'  : 10703,
'developers-institute'  : 10705,
'devmountain'  : 10710,
'digitalcrafts'  : 10719,
'epicodus'  : 10739,
'evolve-security-academy'  : 10743,
'flatiron-school'  : 10748,
'general-assembly'  : 10761,
'greyatom-school-of-data-science'  : 10776,
'h-academy'  : 11518,
'hack-reactor'  : 10788,
'hacktiv8'  : 10791,
'hackwagon-academy'  : 10792,
'heicoders-academy'  : 11287,
'holberton-school'  : 10796,
'hyperiondev'  : 10801,
'ironhack'  : 10828,
'jedha'  : 10837,
'juno-college-of-technology'  : 10787,
'kenzie-academy'  : 10843,
'knowledgehut'  : 10846,
'la-capsule'  : 10853,
'learningfuze'  : 10862,
'le-wagon'  : 10868,
'lighthouse-labs'  : 10869,
'makers-academy'  : 10874,
'microverse'  : 10888,
'neoland'  : 10906,
'nucamp'  : 10923,
'nyc-data-science-academy'  : 10925,
'practicum'  : 11225,
'product-gym'  : 10959,
'product-school'  : 10960,
'react-graphql-academy'  : 10972,
'rmotr'  : 10987,
'rocket-academy'  : 11483,
'school-of-it'  : 11006,
'shecodes'  : 11014,
'simplilearn'  : 11016,
'sit-academy'  : 10965,
'skillcrush'  : 11020,
'software-development-academy'  : 11030,
'springboard'  : 11035,
'startup-institute'  : 11042,
'tech-elevator'  : 11056,
'tech-talent-south'  : 11059,
'the-job-hackers'  : 11085,
'the-tech-academy'  : 11091,
'thinkful'  : 11098,
'udacity'  : 11118,
'ux-design-institute'  : 11150,
'uxer-school'  : 11151,
'wild-code-school'  : 11169,
'wyncode'  : 11174,
'xccelerate'  : 11175,

}

# %% [markdown]
# # Functions

# %%
#Function for Scraping 
def get_comments_school(school):
    #This function extracts all the 
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
#get_comments_school('wyncode')

# %%
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# 4geeks-academy
# academia-de-codigo
# actualize
# altcademy
# app-academy
# bloomtech
# brainstation
# careerfoundry
# careerist
# claim-academy
# clarusway
# code-fellows
# code-institute
# codesmith
# codeworks
# coding-bootcamp-praha
# coding-dojo
# coding-temple
# datacamp
# dataquest
# data-science-dojo
# datascientest
# designlab
# devcodecamp
# developers-institute
# devmountain
# digitalcrafts
# epicodus
# evolve-security-academy
# flatiron-school
# general-assembly
# greyatom-school-of-data-science
# h-academy
# hack-reactor
# hacktiv8
# hackwagon-academy
# heicoders-academy
# holberton-school
# hyperiondev
# ironhack
# jedha
# juno-college-of-technology
# kenzie-academy
# knowledgehut
# la-capsule
# learningfuze
# le-wagon
# lighthouse-labs
# makers-academy
# microverse
# neoland
# nucamp
# nyc-data-science-academy
# practicum
# product-gym
# product-school
# react-graphql-academy
# rmotr
# rocket-academy
# school-of-it
# shecodes
# simplilearn
# sit-academy
# skillcrush
# software-development-academy
# springboard
# startup-institute
# tech-elevator
# tech-talent-south
# the-job-hackers
# the-tech-academy
# thinkful
# udacity
# ux-design-institute
# uxer-school
# wild-code-school
# wyncode
# xccelerate

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

# %%
locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# 4geeks-academy
# /var/folders/qc/598rf5kn0sz5cshnx3dqfdlw0000gn/T/ipykernel_14697/4240401434.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# academia-de-codigo
# actualize
# altcademy
# app-academy
# bloomtech
# brainstation
# careerfoundry
# careerist
# claim-academy
# clarusway
# code-fellows
# code-institute
# codesmith
# codeworks
# coding-bootcamp-praha
# coding-dojo
# coding-temple
# datacamp
# dataquest
# data-science-dojo
# datascientest
# designlab
# devcodecamp
# developers-institute
# devmountain
# digitalcrafts
# epicodus
# evolve-security-academy
# flatiron-school
# general-assembly
# greyatom-school-of-data-science
# h-academy
# hack-reactor
# hacktiv8
# hackwagon-academy
# heicoders-academy
# holberton-school
# hyperiondev
# ironhack
# jedha
# juno-college-of-technology
# kenzie-academy
# knowledgehut
# la-capsule
# learningfuze
# le-wagon
# lighthouse-labs
# makers-academy
# microverse
# neoland
# nucamp
# nyc-data-science-academy
# practicum
# product-gym
# product-school
# react-graphql-academy
# rmotr
# rocket-academy
# school-of-it
# shecodes
# simplilearn
# sit-academy
# skillcrush
# software-development-academy
# springboard
# startup-institute
# tech-elevator
# tech-talent-south
# the-job-hackers
# the-tech-academy
# thinkful
# udacity
# ux-design-institute
# uxer-school
# wild-code-school
# wyncode
# xccelerate

# %%
#Dataframes creation 
locations = pd.concat(locations_list)
courses = pd.concat(courses_list)
badges = pd.concat(badges_list)
schools = pd.concat(schools_list)

# %%
#Function to clean
def clean_text_tag(col):
    col.str.replace('<span class="truncatable"><p></p><p>','')
    col.str.replace('<span class="truncatable"><p>','')
    col.str.replace('<p>','')
    col.str.replace('</p>','')

# %% [markdown]
# # Dataframes exploration

# %%
# Tables / dataframes
    # comments
    # locations
    # courses
    # badges
    # schools

# %%
#Sizes for all
print('Comments',comments.shape)
print('locations',locations.shape)
print('courses',courses.shape)
print('badges',badges.shape)
print('schools',schools.shape)
# Out:
# Comments (23981, 21)
# locations (506, 14)
# courses (536, 3)
# badges (163, 5)
# schools (78, 5)

# %% [markdown]
# ### We start exploring for cleaning process by table/dataframe

# %%
#we start with comments
comments.describe()
# Out:
#                   id  graduatingYear
# count   23981.000000    23746.000000
# mean   257609.910804     2018.815590
# std     16296.630550        1.838814
# min    231508.000000     2010.000000
# 25%    243260.000000     2018.000000
# 50%    257234.000000     2019.000000
# 75%    271372.000000     2020.000000
# max    287375.000000     2022.000000

# %%
comments.sample(15)
# Out:
#           id                    name  anonymous       hostProgramName  \
# 8     284621                     Dan      False                  None
# 586   255838               Anonymous       True  Software Engineering
# 1595  244436             Haruka Aoki      False  Software Engineering
# 85    235260           Karina Amador      False          UX/UI Design
# 224   269909               Anonymous       True                  None
# 3     286956             Aurore HUET      False                  None
# 201   281530              Fiona Dean      False                  None
# 539   252618               Anonymous       True                  None
# 168   266454          Susanne Aubert      False          UX/UI Design
# 356   272255         Sadegh Houshyar      False                  None
# 11    265401                    Petr      False  Software Engineering
# 83    251146           Sarah Steiner      False  Software Engineering
# 11    285825            Helen Cheung      False                  None
# 44    267733  Ridhvik Rohan Oruganti      False                  None
# 33    253342               Stephanie      False                  None
#
#       graduatingYear isAlumni            jobTitle  \
# 8             2021.0    False
# 586           2019.0     True                None
# 1595          2018.0     True                None
# 85            2018.0     True  Software developer
# 224           2020.0     True
# 3             2022.0    False      Consultant  IT
# 201           2021.0    False        Data Analyst
# 539           2019.0     True                None
# 168           2020.0    False      UX/UI Designer
# 356           2020.0    False        Data Analyst
# 11            2020.0    False       Web Developer
# 83            2019.0     True                None
# 11            2022.0    False             Manager
# 44            2020.0     True
# 33            2019.0     True             student
#
#                                                 tagline  \
# 8                                   Following My Dreams
# 586                       The experience was very good.
# 1595  My best and hardest experience in beautiful ci...
# 85                            Life changing experience.
# 224                                      awesome course
# 3     Formation continue Data analyst suivie de Juil...
# 201                              Enjoyed the curriculum
# 539                                         interesting
# 168                         A great learning experience
# 356                                 highly recommended!
# 11        My journey from automotive to web development
# 83                            devCodeCamp is liberating
# 11                 Fast paced but rewarding experience!
# 44    @Simplilearn strikes your career-----&gt;"SUCC...
# 33                     Tech Talent South Java boot camp
#
#                                                    body  \
# 8     <span class="truncatable"><p></p><p>I've known...
# 586   <p>The Price of NuCamp is very affordable and ...
# 1595  <span class="truncatable"><p>Firstly, Barcelon...
# 85    <span class="truncatable"><p>I have a communic...
# 224   <span class="truncatable"><p>loved this course...
# 3     <span class="truncatable"><p></p><p>Formation ...
# 201   <span class="truncatable"><p></p><p>It was ver...
# 539   <p>it was interesting learning about python an...
# 168   <span class="truncatable"><p></p><p>Ironhack w...
# 356   <span class="truncatable"><p></p><p>Thanks to ...
# 11    <span class="truncatable"><p></p><p>As a forme...
# 83    <span class="truncatable"><p>I will forever be...
# 11    <span class="truncatable"><p></p><p>I am glad ...
# 44    <span class="truncatable"><p>Learning this cou...
# 33    <span class="truncatable"><p>I know my title r...
#
#                                                 rawBody  ...   queryDate  \
# 8     <p>I&#39;ve known for a long time that I wante...  ...  2021-12-30
# 586   The Price of NuCamp is very affordable and you...  ...  2019-10-01
# 1595  Firstly, Barcelona is the best city ever even ...  ...  2018-08-07
# 85    I have a communications and digital marketing ...  ...  2018-06-13
# 224   loved this course, it was super challenging bu...  ...  2020-11-01
# 3     <p>Formation tr&egrave;s solide et exigeante q...  ...  2022-03-21
# 201   <p>It was very easy to move through the curric...  ...  2021-09-17
# 539   it was interesting learning about python and p...  ...  2019-08-04
# 168   <p>Ironhack was such a positive experience for...  ...  2020-07-16
# 356   <p>Thanks to Le Wagon, my dream to become a da...  ...  2021-01-14
# 11    <p>As a former sales specialist working in the...  ...  2020-06-12
# 83    I will forever be grateful to devCodeCamp. Wha...  ...  2019-05-14
# 11    <p>I am glad to have done an in-person course ...  ...  2022-02-11
# 44    Learning this course eventually made me improv...  ...  2020-08-23
# 33    I know my title reads Java boot camp but we di...  ...  2019-07-22
#
#                                                 program             user  \
# 8                                       Web Development  {'image': None}
# 586                                                None  {'image': None}
# 1595                  FullStack program - 35+ locations  {'image': None}
# 85    Code 301: Intermediate Software Development - ...  {'image': None}
# 224                        Web Development Fundamentals  {'image': None}
# 3                     Data Analyst - 9 weeks / 6 months  {'image': None}
# 201                         Data Analytics Career Track  {'image': None}
# 539                                                None  {'image': None}
# 168                                                      {'image': None}
# 356                            Data Science - Full-Time  {'image': None}
# 11                                                       {'image': None}
# 83                     Full Stack Software Development   {'image': None}
# 11                               Data Science Part-Time  {'image': None}
# 44                     Intro to Python for Data Science  {'image': None}
# 33                                                 None  {'image': None}
#
#      overallScore comments overall curriculum jobSupport  \
# 8             5.0       []     5.0        5.0        5.0
# 586           5.0       []     5.0        5.0        NaN
# 1595          5.0       []     5.0        5.0        5.0
# 85            4.7       []     5.0        5.0        4.0
# 224           5.0       []     5.0        5.0        5.0
# 3             5.0       []     5.0        5.0        5.0
# 201           4.3       []     4.0        5.0        4.0
# 539           5.0       []     5.0        5.0        NaN
# 168           4.7       []     5.0        5.0        4.0
# 356           5.0       []     5.0        5.0        5.0
# 11            5.0       []     5.0        5.0        5.0
# 83            5.0       []     5.0        5.0        5.0
# 11            5.0       []     5.0        5.0        5.0
# 44            4.7       []     5.0        5.0        4.0
# 33            3.0       []     5.0        3.0        1.0
#
#                                             review_body                 school
# 8     I've known for a long time that I wanted to de...            devcodecamp
# 586   The Price of NuCamp is very affordable and you...                 nucamp
# 1595  Firstly, Barcelona is the best city ever even ...               le-wagon
# 85    I have a communications and digital marketing ...           code-fellows
# 224   loved this course, it was super challenging bu...                 nucamp
# 3     Formation très solide et exigeante qui demande...          datascientest
# 201   It was very easy to move through the curriculu...            springboard
# 539   it was interesting learning about python and p...      hackwagon-academy
# 168   Ironhack was such a positive experience for me...               ironhack
# 356   Thanks to Le Wagon, my dream to become a data ...               le-wagon
# 11    As a former sales specialist working in the au...  coding-bootcamp-praha
# 83    I will forever be grateful to devCodeCamp. Wha...            devcodecamp
# 11    I am glad to have done an in-person course as ...              h-academy
# 44    Learning this course eventually made me improv...               datacamp
# 33    I know my title reads Java boot camp but we di...      tech-talent-south
#
# [15 rows x 21 columns]

# %%
# Review types for the columns
#We can see that some columns should be numbers float/int and they arent 
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear     float64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore        object
# comments            object
# overall             object
# curriculum          object
# jobSupport          object
# review_body         object
# school              object
# dtype: object

# %%
#Validation for empty values
comments.isnull().sum()
# Out:
# id                     0
# name                   0
# anonymous              0
# hostProgramName    13383
# graduatingYear       235
# isAlumni              17
# jobTitle            9285
# tagline                3
# body                   0
# rawBody                0
# createdAt              0
# queryDate              0
# program             3663
# user                   0
# overallScore          48
# comments               0
# overall               50
# curriculum           878
# jobSupport          3170
# review_body            0
# school                 0
# dtype: int64

# %%
#There are empty spaces
comments[comments['overallScore'].isnull()].count()
# Out:
# id                 48
# name               48
# anonymous          48
# hostProgramName    11
# graduatingYear     41
# isAlumni           48
# jobTitle            7
# tagline            47
# body               48
# rawBody            48
# createdAt          48
# queryDate          48
# program            24
# user               48
# overallScore        0
# comments           48
# overall             0
# curriculum          0
# jobSupport          0
# review_body        48
# school             48
# dtype: int64

# %%
comments['overallScore'].unique()
# Out:
# array(['5.0', '3.7', '2.0', '4.7', '4.3', '3.0', '4.0', '4.5', '3.5',
#        '3.3', '2.3', '1.7', '1.5', '1.0', '2.7', '1.3', '2.5', None,
#        '4.2', '4.8', '3.2'], dtype=object)

# %%
comments['overall'].unique()
# Out:
# array(['5.0', '2.0', '4.0', '3.0', '1.0', nan, '4.5', '3.5'], dtype=object)

# %%
comments['overallScore'].value_counts()
# Out:
# 5.0    15824
# 4.7     2945
# 4.3     1668
# 4.0     1490
# 3.7      567
# 4.5      264
# 1.0      230
# 3.3      226
# 3.0      221
# 2.0      116
# 2.7       92
# 2.3       80
# 1.7       73
# 1.3       68
# 3.5       34
# 2.5       16
# 1.5       15
# 4.2        2
# 4.8        1
# 3.2        1
# Name: overallScore, dtype: int64

# %%
comments['overall'].value_counts()
# Out:
# 5.0    20211
# 4.0     2789
# 3.0      359
# 1.0      348
# 2.0      218
# 4.5        5
# 3.5        1
# Name: overall, dtype: int64

# %%
comments['comments'].isnull().sum()
# Out:
# 0

# %%
comments['curriculum'].unique()
# Out:
# array(['5.0', '2.0', '4.0', '3.0', nan, '1.0', '2.5'], dtype=object)

# %%
comments['jobSupport'].unique()
# Out:
# array(['5.0', '1.0', '2.0', '3.0', '4.0', nan], dtype=object)

# %% [markdown]
# ## Cleanning proccess for all the tables

# %% [markdown]
# ### Table comments

# %%
comments[['overallScore','overall','curriculum','jobSupport']] = comments[['overallScore','overall','curriculum','jobSupport']].astype('float64')

# %%
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear     float64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore       float64
# comments            object
# overall            float64
# curriculum         float64
# jobSupport         float64
# review_body         object
# school              object
# dtype: object

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022., 2021., 2020., 2019., 2018., 2016., 2017., 2015., 2014.,
#        2012.,   nan, 2011., 2013., 2010.])

# %%
#For empty/nan we will replace it with 0 , it Could be another Value like No Date
comments['graduatingYear'] = comments['graduatingYear'].fillna(0)

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022., 2021., 2020., 2019., 2018., 2016., 2017., 2015., 2014.,
#        2012.,    0., 2011., 2013., 2010.])

# %%
#pd.to_datetime(comments['graduatingYear'])
#comments['graduatingYear'].dt.strftime('%d.%m.%Y')

comments['graduatingYear'] = comments['graduatingYear'].astype('int64')

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2016, 2017, 2015, 2014, 2012,    0,
#        2011, 2013, 2010])

# %%
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear       int64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore       float64
# comments            object
# overall            float64
# curriculum         float64
# jobSupport         float64
# review_body         object
# school              object
# dtype: object

# %%
#Changing column to datetime type
comments['queryDate'] = pd.to_datetime(comments['queryDate'])
#comments['queryDate'].dt.strftime('%d.%m.%Y')
comments['queryDate']
# Out:
# 0     2022-04-01
# 1     2022-03-24
# 2     2022-03-23
# 3     2022-03-17
# 4     2022-03-17
#          ...
# 181   2017-11-28
# 182   2017-10-25
# 183   2017-10-19
# 184   2017-09-13
# 185   2017-08-03
# Name: queryDate, Length: 23981, dtype: datetime64[ns]

# %%
#Changing column to datetime type
comments['createdAt'] = pd.to_datetime(comments['createdAt'])
#comments['queryDate'].dt.strftime('%d.%m.%Y')
comments['createdAt']
# Out:
# 0     2022-04-01
# 1     2022-03-24
# 2     2022-03-23
# 3     2022-03-17
# 4     2022-03-17
#          ...
# 181   2017-11-28
# 182   2017-10-25
# 183   2017-10-19
# 184   2017-09-13
# 185   2017-08-03
# Name: createdAt, Length: 23981, dtype: datetime64[ns]

# %%
comments.dtypes
# Out:
# id                          int64
# name                       object
# anonymous                    bool
# hostProgramName            object
# graduatingYear              int64
# isAlumni                   object
# jobTitle                   object
# tagline                    object
# body                       object
# rawBody                    object
# createdAt          datetime64[ns]
# queryDate          datetime64[ns]
# program                    object
# user                       object
# overallScore              float64
# comments                   object
# overall                   float64
# curriculum                float64
# jobSupport                float64
# review_body                object
# school                     object
# dtype: object

# %%
comments.sample(3)
# Out:
#           id            name  anonymous       hostProgramName  graduatingYear  \
# 1042  256719   Ziyad Elgendy      False                  None            2015
# 108   254385  Miguel Pereira      False  Software Engineering            2019
# 13    250524       Anonymous       True                  None            2019
#
#      isAlumni              jobTitle                tagline  \
# 1042    False                  None    Great for beginners
# 108      True                  None  Avant-garde Education
# 13       True  Director of Research       ¡Muy buen curso!
#
#                                                    body  \
# 1042  <span class="truncatable"><p>I had the chance ...
# 108   <p><p>A unique and exciting experience packed ...
# 13    <p>Loe mejor: Buen material, excelentes profes...
#
#                                                 rawBody  ...  queryDate  \
# 1042  I had the chance to enroll in the intro to pro...  ... 2019-10-11
# 108   <p>A unique and exciting experience packed wit...  ... 2019-09-11
# 13    Loe mejor: Buen material, excelentes profesore...  ... 2019-07-03
#
#      program             user overallScore  comments overall  curriculum  \
# 1042    None  {'image': None}          4.7        []     5.0         4.0
# 108           {'image': None}          5.0        []     5.0         5.0
# 13      None  {'image': None}          4.0        []     4.0         4.0
#
#       jobSupport                                        review_body  \
# 1042         5.0  I had the chance to enroll in the intro to pro...
# 108          5.0  A unique and exciting experience packed with n...
# 13           4.0  Loe mejor: Buen material, excelentes profesore...
#
#                   school
# 1042             udacity
# 108   academia-de-codigo
# 13           uxer-school
#
# [3 rows x 21 columns]

# %%
#Not usefull columns
# user
comments['user'].sample(4)
# Out:
# 79     {'image': None}
# 235    {'image': None}
# 115    {'image': None}
# 522    {'image': None}
# Name: user, dtype: object

# %%
#Already droped,
#comments.drop(['user'],axis=1,inplace=True)

# %%
comments.head()
# Out:
#        id                  name  anonymous hostProgramName  graduatingYear  \
# 0  287305  Javier Leyva Seiglie      False            None            2022
# 1  287077         Oswaldo Salas      False            None            2021
# 2  287024         Oswaldo Salas      False            None            2021
# 3  286880       Aaron Arismendi      False            None            2021
# 4  286878          Octavio Lara      False            None            2021
#
#   isAlumni                  jobTitle  \
# 0    False  Full Stack web developer
# 1    False
# 2    False
# 3    False  Desarrollador Full Stack
# 4    False         Software engineer
#
#                                      tagline  \
# 0          On a simple word, the actual best
# 1  Obtener mucho conocimiento sin frustrarte
# 2  Obtener mucho conocimiento sin frustrarte
# 3                      Una experiencia única
# 4                    A fulfilling experience
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>This is a ...
# 1  <span class="truncatable"><p></p><p>Me gusto m...
# 2  <span class="truncatable"><p></p><p>Particular...
# 3  <span class="truncatable"><p></p><p>No sabía n...
# 4  <span class="truncatable"><p></p><p>I'd say th...
#
#                                              rawBody  ...  queryDate  \
# 0  <p>This is a beast! The best! I attain the ful...  ... 2022-04-01
# 1  <p>Me gusto mucho la din&aacute;mica para ir s...  ... 2022-03-24
# 2  <p>Particularmente creo que el programa de ent...  ... 2022-03-23
# 3  <p>No sab&iacute;a nada a cerca de programaci&...  ... 2022-03-17
# 4  <p>I&#39;d say the main pro would be the commu...  ... 2022-03-17
#
#                                      program             user overallScore  \
# 0            Full Stack Software Development  {'image': None}          5.0
# 1            Full Stack Software Development  {'image': None}          5.0
# 2            Full Stack Software Development  {'image': None}          3.7
# 3            Full Stack Software Development  {'image': None}          5.0
# 4  Full Stack Software Development Part Time  {'image': None}          5.0
#
#    comments overall  curriculum  jobSupport  \
# 0        []     5.0         5.0         5.0
# 1        []     5.0         5.0         5.0
# 2        []     5.0         5.0         1.0
# 3        []     5.0         5.0         5.0
# 4        []     5.0         5.0         5.0
#
#                                          review_body          school
# 0  This is a beast! The best! I attain the full s...  4geeks-academy
# 1  Me gusto mucho la dinámica para ir superando c...  4geeks-academy
# 2  Particularmente creo que el programa de entren...  4geeks-academy
# 3  No sabía nada a cerca de programación hasta qu...  4geeks-academy
# 4  I'd say the main pro would be the community. T...  4geeks-academy
#
# [5 rows x 21 columns]

# %%
#Adjust Text eliminaring <p>
comments['rawBody'] = comments['rawBody'].str.replace('<p>','')
comments['rawBody']
#= comments['rawBody']
# Out:
# 0      This is a beast! The best! I attain the full s...
# 1      Me gusto mucho la din&aacute;mica para ir supe...
# 2      Particularmente creo que el programa de entren...
# 3      No sab&iacute;a nada a cerca de programaci&oac...
# 4      I&#39;d say the main pro would be the communit...
#                              ...
# 181    You never know how you can improve if you don'...
# 182    This course has provided me with the right too...
# 183    Nice bootcamp for people to learn who to codin...
# 184    Everything I learned was broad enough to be re...
# 185    Accelerate was a good choice for me because I ...
# Name: rawBody, Length: 23981, dtype: object

# %%
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p></p><p>','')
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p>','')
comments['body'] = comments['body'].str.replace('<p>','')
badges['description'] = badges['description'].str.replace('</p>','')
comments['body'].sample(6)
# Out:
# 431    Pros <br>- mentors were experienced and friend...
# 81     I loved attending devCodeCamp 3 years ago. Whe...
# 19     I was looking for a remote job as a customer s...
# 801    I attended Le Wagon Paris in fall 2019 and it ...
# 603    I joined Bloc back in April of 2015, before th...
# 148    There is a lot to learn in this course and the...
# Name: body, dtype: object

# %%
comments.sample(5)
# Out:
#           id            name  anonymous       hostProgramName  graduatingYear  \
# 10    274287       Anonymous       True                  None            2020
# 1810  242162  Maxime Blondel      False  Software Engineering            2017
# 1820  242009  Andrew Gilbert      False  Software Engineering            2017
# 300   233279       Anonymous      False                  None            2016
# 45    281345           Kamel      False                  None            2021
#
#      isAlumni                  jobTitle  \
# 10      False            Data Associate
# 1810     True                 Freelance
# 1820     True  Front-End JavaScript Dev
# 300      True                      None
# 45      False
#
#                                                 tagline  \
# 10    Excellent program to provide structure and car...
# 1810   Le Wagon changed my life (and they had warned !)
# 1820  The most worthwhile 9-weeks, truly life-changing.
# 300   Data Science with R: Data Analysis and Visuali...
# 45                            Only good things to say !
#
#                                                    body  \
# 10    Flatiron School's Online Data Science Immersiv...
# 1810  An incredible experience from beginning to end...
# 1820  I'm going to start this testimonial with an un...
# 300   Great course! The slides were clear and the co...
# 45    I do believe the fullstack formation is the be...
#
#                                                 rawBody  ...  queryDate  \
# 10    Flatiron School&#39;s Online Data Science Imme...  ... 2021-03-03
# 1810  An incredible experience from beginning to end...  ... 2018-02-05
# 1820  I'm going to start this testimonial with an un...  ... 2018-01-26
# 300   Great course! The slides were clear and the co...  ... 2016-12-04
# 45    I do believe the fullstack formation is the be...  ... 2021-09-10
#
#                                                 program             user  \
# 10                                  Online Data Science  {'image': None}
# 1810                  FullStack program - 35+ locations  {'image': None}
# 1820                  FullStack program - 35+ locations  {'image': None}
# 300   Data Science with Python: Data Analysis and Vi...  {'image': None}
# 45                   Fullstack JavaScript Web Developer  {'image': None}
#
#      overallScore  comments overall  curriculum  jobSupport  \
# 10            4.7        []     5.0         4.0         5.0
# 1810          5.0        []     5.0         5.0         5.0
# 1820          5.0        []     5.0         5.0         5.0
# 300           5.0        []     5.0         5.0         5.0
# 45            5.0        []     5.0         5.0         5.0
#
#                                             review_body  \
# 10    Flatiron School's Online Data Science Immersiv...
# 1810  An incredible experience from beginning to end...
# 1820  I'm going to start this testimonial with an un...
# 300   Great course! The slides were clear and the co...
# 45    I do believe the fullstack formation is the be...
#
#                         school
# 10             flatiron-school
# 1810                  le-wagon
# 1820                  le-wagon
# 300   nyc-data-science-academy
# 45                  la-capsule
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Table locations

# %%
locations.sample(5)
# Out:
#        id               description  country.id    country.name  \
# 65  16880  Omaha, NE, United States         1.0   United States
# 0   16277                    Online         NaN             NaN
# 8   17791     San Juan, Puerto Rico         1.0   United States
# 3   16958           London, England        11.0  United Kingdom
# 2   16462                    Online         NaN             NaN
#
#    country.abbrev  state.id   state.name state.abbrev state.keyword  city.id  \
# 65             US      29.0     Nebraska           NE      nebraska     54.0
# 0             NaN       1.0       Online       Online        online      NaN
# 8              US      55.0  Puerto Rico           PR           NaN   5104.0
# 3              GB       NaN          NaN          NaN           NaN  31176.0
# 2             NaN       1.0       Online       Online        online      NaN
#
#    city.name city.keyword            school  school_id
# 65     Omaha        omaha            nucamp      10923
# 0        NaN          NaN          datacamp      10682
# 8   San Juan     san-juan  holberton-school      10796
# 3     London       london   flatiron-school      10748
# 2        NaN          NaN       hyperiondev      10801

# %%
locations.dtypes
# Out:
# id                  int64
# description        object
# country.id        float64
# country.name       object
# country.abbrev     object
# state.id          float64
# state.name         object
# state.abbrev       object
# state.keyword      object
# city.id           float64
# city.name          object
# city.keyword       object
# school             object
# school_id           int64
# dtype: object

# %%
#Validation for empty values
locations.isnull().sum()
# Out:
# id                  0
# description         0
# country.id         65
# country.name       65
# country.abbrev     65
# state.id          228
# state.name        228
# state.abbrev      228
# state.keyword     229
# city.id            66
# city.name          66
# city.keyword       66
# school              0
# school_id           0
# dtype: int64

# %%
locations.isna()
# Out:
#        id  description  country.id  country.name  country.abbrev  state.id  \
# 0   False        False       False         False           False     False
# 1   False        False       False         False           False      True
# 2   False        False       False         False           False      True
# 3   False        False       False         False           False      True
# 4   False        False       False         False           False      True
# ..    ...          ...         ...           ...             ...       ...
# 24  False        False        True          True            True     False
# 25  False        False       False         False           False      True
# 0   False        False       False         False           False     False
# 0   False        False       False         False           False      True
# 1   False        False        True          True            True     False
#
#     state.name  state.abbrev  state.keyword  city.id  city.name  city.keyword  \
# 0        False         False          False    False      False         False
# 1         True          True           True    False      False         False
# 2         True          True           True    False      False         False
# 3         True          True           True    False      False         False
# 4         True          True           True    False      False         False
# ..         ...           ...            ...      ...        ...           ...
# 24       False         False          False     True       True          True
# 25        True          True           True    False      False         False
# 0        False         False          False    False      False         False
# 0         True          True           True    False      False         False
# 1        False         False          False     True       True          True
#
#     school  school_id
# 0    False      False
# 1    False      False
# 2    False      False
# 3    False      False
# 4    False      False
# ..     ...        ...
# 24   False      False
# 25   False      False
# 0    False      False
# 0    False      False
# 1    False      False
#
# [506 rows x 14 columns]

# %%
locations[['description','country.id','country.name']].sample(4)
#Empty conuntries is bevause is online
# Out:
#                        description  country.id   country.name
# 52  Los Angeles, CA, United States         1.0  United States
# 1       Johannesburg, South Africa        17.0   South Africa
# 5                           Online         NaN            NaN
# 0                  Dublin, Ireland        25.0        Ireland

# %%
locations['description'][locations['country.name'].isnull()].unique()
# Out:
# array(['Online'], dtype=object)

# %% [markdown]
# ### Table courses

# %%
#This one looks ok
courses
# Out:
#                                               courses              school  \
# 0          Ai and Machine Learning Full-Stack Program      4geeks-academy
# 1                     Full Stack Software Development      4geeks-academy
# 2           Full Stack Software Development Part Time      4geeks-academy
# 0   14-Week Intensive && Immersive Full-Stack Prog...  academia-de-codigo
# 0                Actualize Coding Bootcamp: Full-Time           actualize
# ..                                                ...                 ...
# 5       Data Science and Machine Learning (Part-time)          xccelerate
# 6                                  Python for Finance          xccelerate
# 7                                 Python Fundamentals          xccelerate
# 8   Software Engineering Immersive Bootcamp (Full-...          xccelerate
# 9                                           UX Design          xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 2       10492
# 0       10494
# 0       10505
# ..        ...
# 5       11175
# 6       11175
# 7       11175
# 8       11175
# 9       11175
#
# [536 rows x 3 columns]

# %%
courses.dtypes
# Out:
# courses      object
# school       object
# school_id     int64
# dtype: object

# %% [markdown]
# ### Table badges

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0               <p>School offers fully online courses  4geeks-academy
# 1      <p>School offers part-time and evening classes  4geeks-academy
# 0               <p>School offers fully online courses       actualize
# 1      <p>School offers part-time and evening classes       actualize
# 0               <p>School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   <p>School publishes a third-party verified out...         wyncode
# 2      <p>School offers part-time and evening classes         wyncode
# 3                       <p>School accepts the GI Bill         wyncode
# 0               <p>School offers fully online courses      xccelerate
# 1      <p>School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %%
badges.dtypes
# Out:
# name           object
# keyword        object
# description    object
# school         object
# school_id       int64
# dtype: object

# %%
#For cleaning function
#badges['description'] = badges['description'].apply(clean_text_tag(badges['description']))
#badges['description']

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0               <p>School offers fully online courses  4geeks-academy
# 1      <p>School offers part-time and evening classes  4geeks-academy
# 0               <p>School offers fully online courses       actualize
# 1      <p>School offers part-time and evening classes       actualize
# 0               <p>School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   <p>School publishes a third-party verified out...         wyncode
# 2      <p>School offers part-time and evening classes         wyncode
# 3                       <p>School accepts the GI Bill         wyncode
# 0               <p>School offers fully online courses      xccelerate
# 1      <p>School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %%
#Clean text from tags
badges['description'] = badges['description'].str.replace('<span class="truncatable"><p></p><p>','')
badges['description'] = badges['description'].str.replace('<span class="truncatable"><p>','')
badges['description'] = badges['description'].str.replace('<p>','')
badges['description'] = badges['description'].str.replace('</p>','')
badges['description'].sample(6)
# Out:
# 0                   School offers fully online courses
# 0                   School offers fully online courses
# 0                   School offers fully online courses
# 0                   School offers fully online courses
# 1    School publishes a third-party verified outcom...
# 2          School offers part-time and evening classes
# Name: description, dtype: object

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0                  School offers fully online courses  4geeks-academy
# 1         School offers part-time and evening classes  4geeks-academy
# 0                  School offers fully online courses       actualize
# 1         School offers part-time and evening classes       actualize
# 0                  School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   School publishes a third-party verified outcom...         wyncode
# 2         School offers part-time and evening classes         wyncode
# 3                          School accepts the GI Bill         wyncode
# 0                  School offers fully online courses      xccelerate
# 1         School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %% [markdown]
# ### Table schools

# %%
schools
# Out:
#                                               website  \
# 0                                www.4geeksacademy.co
# 0                        applyto.academiadecodigo.org
# 0   anyonecanlearntocode.com/?utm_source=switchup&...
# 0                                   www.altcademy.com
# 0                                       appacademy.io
# ..                                                ...
# 0                              uxdesigninstitute.com/
# 0                                  www.uxerschool.com
# 0                                  wildcodeschool.com
# 0                                      www.wyncode.co
# 0                                       xccelerate.co
#
#                                           description  \
# 0   <span class="truncatable"><p>4Geeks Academy is...
# 0   <span class="truncatable"><p>Founded in Lisbon...
# 0   <span class="truncatable"><p>Actualize is a co...
# 0   <span class="truncatable"><p>Altcademy is a 10...
# 0   <span class="truncatable"><p>App Academy is a ...
# ..                                                ...
# 0   <span class="truncatable"><p>The UX Design Ins...
# 0   <span class="truncatable"><p>UXER School is an...
# 0   <span class="truncatable"><p>Wild Code School ...
# 0   <span class="truncatable"><p>Wyncode Academy i...
# 0   <span class="truncatable"><p>Xccelerate is a s...
#
#                                               LogoUrl               school  \
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...       4geeks-academy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...   academia-de-codigo
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            actualize
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            altcademy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# ..                                                ...                  ...
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...  ux-design-institute
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          uxer-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...     wild-code-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...              wyncode
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...           xccelerate
#
#     school_id
# 0       10492
# 0       10494
# 0       10505
# 0       10517
# 0       10525
# ..        ...
# 0       11150
# 0       11151
# 0       11169
# 0       11174
# 0       11175
#
# [78 rows x 5 columns]

# %%
schools.dtypes
# Out:
# website        object
# description    object
# LogoUrl        object
# school         object
# school_id       int64
# dtype: object

# %%
#Clean text from tags
schools['description'] = schools['description'].str.replace('<span class="truncatable"><p></p><p>','')
schools['description'] = schools['description'].str.replace('<span class="truncatable"><p>','')
schools['description'] = schools['description'].str.replace('<p>','')
schools['description'] = schools['description'].str.replace('</p>','')
schools['description'].sample(6)
# Out:
# 0    Springboard is an online learning platform tha...
# 0    Skillcrush has more than 17,000 students in al...
# 0    Claim Academy is a premier developer boot camp...
# 0    Wyncode Academy is a premier technical educato...
# 0    The UX Design Institute offers 6 month, online...
# 0    DigitalCrafts is the top-reviewed coding bootc...
# Name: description, dtype: object

# %%
schools
# Out:
#                                               website  \
# 0                                www.4geeksacademy.co
# 0                        applyto.academiadecodigo.org
# 0   anyonecanlearntocode.com/?utm_source=switchup&...
# 0                                   www.altcademy.com
# 0                                       appacademy.io
# ..                                                ...
# 0                              uxdesigninstitute.com/
# 0                                  www.uxerschool.com
# 0                                  wildcodeschool.com
# 0                                      www.wyncode.co
# 0                                       xccelerate.co
#
#                                           description  \
# 0   4Geeks Academy is a Coding Bootcamp focused on...
# 0   Founded in Lisbon in 2015, this Portuguese-bor...
# 0   Actualize is a coding bootcamp that values qua...
# 0   Altcademy is a 100% online education institute...
# 0   App Academy is a coding school that offers onl...
# ..                                                ...
# 0   The UX Design Institute offers 6 month, online...
# 0   UXER School is an education startup, specializ...
# 0   Wild Code School offers 5-month web developmen...
# 0   Wyncode Academy is a premier technical educato...
# 0   Xccelerate is a socially-aligned education sta...
#
#                                               LogoUrl               school  \
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...       4geeks-academy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...   academia-de-codigo
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            actualize
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            altcademy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# ..                                                ...                  ...
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...  ux-design-institute
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          uxer-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...     wild-code-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...              wyncode
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...           xccelerate
#
#     school_id
# 0       10492
# 0       10494
# 0       10505
# 0       10517
# 0       10525
# ..        ...
# 0       11150
# 0       11151
# 0       11169
# 0       11174
# 0       11175
#
# [78 rows x 5 columns]

# %%
# Reseting all indexes

comments = comments.reset_index()
locations = locations.reset_index()
badges = badges.reset_index()
schools = schools.reset_index()
courses = courses.reset_index()

# %%
# Dropped columns: "user" and "comments" in comments to avoid problems 

comments.drop(['user','comments'], axis='columns', inplace=True)

# %% [markdown]
# ## Sending dataframes to MySQL

# %%
import mysql.connector
import getpass

saved_password = getpass.getpass()
cnx = mysql.connector.connect(user = 'root', # Specify your user 
                              password = saved_password, 
                              host ='localhost', 
                              database = 'sakila',
                              auth_plugin='mysql_native_password')
# Out:
# ········

# %%
cnx.is_connected()
if cnx.is_connected():
    print("Connection open")
    # do stuff you need to the database
else:
    print("Connection is not successfully open")
# Out:
# Connection open

# %%
cursor = cnx.cursor()

#Create database

def sql_db(db_name):
    query = f"CREATE DATABASE {db_name}"
    print(query)
    use_db = f"USE {db_name}"
    print(use_db)
    cursor.execute(query)
    cursor.execute(use_db)
    return db_name 

#Execute the full process of a query

def sql_action():
    query = input('Please write your query...')
    #cursor.execute(query,multi=True)
    results = cursor.fetchall()
    results_df = pd.DataFrame(results)
    return "Action completed" 

#Finalize SQL process

def sql_close_connection():
    return cnx.commit(), cursor.close(), cnx.close()

# %%
# Creating database - create it as string

db = sql_db("sql_project")
# Out:
# CREATE DATABASE sql_project
# USE sql_project
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /var/folders/qc/598rf5kn0sz5cshnx3dqfdlw0000gn/T/ipykernel_14697/1638979507.py in <module>
#       1 # Creating database - create it as string
#       2
# ----> 3 db = sql_db("sql_project")
#
# /var/folders/qc/598rf5kn0sz5cshnx3dqfdlw0000gn/T/ipykernel_14697/2518805014.py in sql_db(db_name)
#       8     use_db = f"USE {db_name}"
#       9     print(use_db)
# ---> 10     cursor.execute(query)
#      11     cursor.execute(use_db)
#      12     return db_name
#
# ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     570
#     571         try:
# --> 572             self._handle_result(self._connection.cmd_query(stmt))
#     573         except errors.InterfaceError:
#     574             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     918         query = bytes(packet)
#     919         try:
# --> 920             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     921         except errors.ProgrammingError as err:
#     922             if err.errno == 3948 and \
#
# ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/connection.py in _handle_result(self, packet)
#     728             return self._handle_eof(packet)
#     729         elif packet[4] == 255:
# --> 730             raise errors.get_exception(packet)
#     731
#     732         # We have a text result set
#
# DatabaseError: 1007 (HY000): Can't create database 'sql_project'; database exists

# %%
# Alchemy setup 

from sqlalchemy import create_engine
import pymysql # run pip install pymysql (pip3 for Mac) 

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw=saved_password,
                               db=db))

# %%
# Alchemy insert values - having problems when looped
badges.to_sql('badges', con = engine, if_exists = 'replace', chunksize = 1000)
locations.to_sql('locations', con = engine, if_exists = 'replace', chunksize = 1000)
courses.to_sql('courses', con = engine, if_exists = 'replace', chunksize = 1000)
schools.to_sql('schools', con = engine, if_exists = 'replace', chunksize = 1000)
comments.to_sql('comments', con = engine, if_exists = 'replace', chunksize = 1000)

# %%
# Setting primary KEYs with pandas default indexes - locations table has already an id so we would need to rename based on another keyword or keep it as level_0
cursor.execute("ALTER TABLE comments ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE schools ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE locations ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE courses ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE badges ADD PRIMARY KEY (level_0)")
cursor.fetchall()
# Out:
# []
