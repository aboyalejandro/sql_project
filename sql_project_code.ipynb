# %%
#Imports

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests

# %% [markdown]
# # Dictionary with top schools

# %%
schools = {   
'4geeks-academy'  : 10492,
'academia-de-codigo'  : 10494,
'actualize'  : 10505,
'altcademy'  : 10517,
'app-academy'  : 10525,
'bloomtech'  : 10854,
'brainstation'  : 10571,
'careerfoundry'  : 10581,
'careerist'  : 11280,
'claim-academy'  : 10589,
'clarusway'  : 11539,
'code-fellows'  : 10614,
'code-institute'  : 10619,
'codesmith'  : 10643,
'codeworks'  : 10650,
'coding-bootcamp-praha'  : 10658,
'coding-dojo'  : 10659,
'coding-temple'  : 10664,
#'correlation-one'  : 11528,
'datacamp'  : 10682,
'dataquest'  : 10683,
'data-science-dojo'  : 10685,
'datascientest'  : 11232,
'designlab'  : 10697,
'devcodecamp'  : 10703,
'developers-institute'  : 10705,
'devmountain'  : 10710,
'digitalcrafts'  : 10719,
'epicodus'  : 10739,
'evolve-security-academy'  : 10743,
'flatiron-school'  : 10748,
'general-assembly'  : 10761,
'greyatom-school-of-data-science'  : 10776,
'h-academy'  : 11518,
'hack-reactor'  : 10788,
'hacktiv8'  : 10791,
'hackwagon-academy'  : 10792,
'heicoders-academy'  : 11287,
'holberton-school'  : 10796,
'hyperiondev'  : 10801,
'ironhack'  : 10828,
'jedha'  : 10837,
'juno-college-of-technology'  : 10787,
'kenzie-academy'  : 10843,
'knowledgehut'  : 10846,
'la-capsule'  : 10853,
'learningfuze'  : 10862,
'le-wagon'  : 10868,
'lighthouse-labs'  : 10869,
'makers-academy'  : 10874,
'microverse'  : 10888,
'neoland'  : 10906,
'nucamp'  : 10923,
'nyc-data-science-academy'  : 10925,
'practicum'  : 11225,
'product-gym'  : 10959,
'product-school'  : 10960,
'react-graphql-academy'  : 10972,
'rmotr'  : 10987,
'rocket-academy'  : 11483,
'school-of-it'  : 11006,
'shecodes'  : 11014,
'simplilearn'  : 11016,
'sit-academy'  : 10965,
'skillcrush'  : 11020,
'software-development-academy'  : 11030,
'springboard'  : 11035,
'startup-institute'  : 11042,
'tech-elevator'  : 11056,
'tech-talent-south'  : 11059,
'the-job-hackers'  : 11085,
'the-tech-academy'  : 11091,
'thinkful'  : 11098,
'udacity'  : 11118,
'ux-design-institute'  : 11150,
'uxer-school'  : 11151,
'wild-code-school'  : 11169,
'wyncode'  : 11174,
'xccelerate'  : 11175,

}

# %% [markdown]
# # Functions

# %%
#Function for Scraping 
def get_comments_school(school):
    #This function extracts all the 
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
#get_comments_school('wyncode')

# %%
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# 4geeks-academy
# academia-de-codigo
# actualize
# altcademy
# app-academy
# bloomtech
# brainstation
# careerfoundry
# careerist
# claim-academy
# clarusway
# code-fellows
# code-institute
# codesmith
# codeworks
# coding-bootcamp-praha
# coding-dojo
# coding-temple
# datacamp
# dataquest
# data-science-dojo
# datascientest
# designlab
# devcodecamp
# developers-institute
# devmountain
# digitalcrafts
# epicodus
# evolve-security-academy
# flatiron-school
# general-assembly
# greyatom-school-of-data-science
# h-academy
# hack-reactor
# hacktiv8
# hackwagon-academy
# heicoders-academy
# holberton-school
# hyperiondev
# ironhack
# jedha
# juno-college-of-technology
# kenzie-academy
# knowledgehut
# la-capsule
# learningfuze
# le-wagon
# lighthouse-labs
# makers-academy
# microverse
# neoland
# nucamp
# nyc-data-science-academy
# practicum
# product-gym
# product-school
# react-graphql-academy
# rmotr
# rocket-academy
# school-of-it
# shecodes
# simplilearn
# sit-academy
# skillcrush
# software-development-academy
# springboard
# startup-institute
# tech-elevator
# tech-talent-south
# the-job-hackers
# the-tech-academy
# thinkful
# udacity
# ux-design-institute
# uxer-school
# wild-code-school
# wyncode
# xccelerate

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

# %%
locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# 4geeks-academy
# /var/folders/qc/598rf5kn0sz5cshnx3dqfdlw0000gn/T/ipykernel_9527/4240401434.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# academia-de-codigo
# actualize
# altcademy
# app-academy
# bloomtech
# brainstation
# careerfoundry
# careerist
# claim-academy
# clarusway
# code-fellows
# code-institute
# codesmith
# codeworks
# coding-bootcamp-praha
# coding-dojo
# coding-temple
# datacamp
# dataquest
# data-science-dojo
# datascientest
# designlab
# devcodecamp
# developers-institute
# devmountain
# digitalcrafts
# epicodus
# evolve-security-academy
# flatiron-school
# general-assembly
# greyatom-school-of-data-science
# h-academy
# hack-reactor
# hacktiv8
# hackwagon-academy
# heicoders-academy
# holberton-school
# hyperiondev
# ironhack
# jedha
# juno-college-of-technology
# kenzie-academy
# knowledgehut
# la-capsule
# learningfuze
# le-wagon
# lighthouse-labs
# makers-academy
# microverse
# neoland
# nucamp
# nyc-data-science-academy
# practicum
# product-gym
# product-school
# react-graphql-academy
# rmotr
# rocket-academy
# school-of-it
# shecodes
# simplilearn
# sit-academy
# skillcrush
# software-development-academy
# springboard
# startup-institute
# tech-elevator
# tech-talent-south
# the-job-hackers
# the-tech-academy
# thinkful
# udacity
# ux-design-institute
# uxer-school
# wild-code-school
# wyncode
# xccelerate

# %%
#Dataframes creation 
locations = pd.concat(locations_list)
courses = pd.concat(courses_list)
badges = pd.concat(badges_list)
schools = pd.concat(schools_list)

# %%
#Function to clean
def clean_text_tag(col):
    col.str.replace('<span class="truncatable"><p></p><p>','')
    col.str.replace('<span class="truncatable"><p>','')
    col.str.replace('<p>','')
    col.str.replace('</p>','')

# %% [markdown]
# # Dataframes exploration

# %%
# Tables / dataframes
    # comments
    # locations
    # courses
    # badges
    # schools

# %%
#Sizes for all
print('Comments',comments.shape)
print('locations',locations.shape)
print('courses',courses.shape)
print('badges',badges.shape)
print('schools',schools.shape)
# Out:
# Comments (23966, 21)
# locations (506, 14)
# courses (536, 3)
# badges (163, 5)
# schools (78, 5)

# %% [markdown]
# ### We start exploring for cleaning process by table/dataframe

# %%
#we start with comments
comments.describe()
# Out:
#                   id  graduatingYear
# count   23966.000000    23731.000000
# mean   257591.294250     2018.813914
# std     16284.725706        1.838075
# min    231508.000000     2010.000000
# 25%    243254.250000     2018.000000
# 50%    257223.500000     2019.000000
# 75%    271350.000000     2020.000000
# max    287341.000000     2022.000000

# %%
comments.sample(15)
# Out:
#           id              name  anonymous       hostProgramName  \
# 370   275537      TAYLOR MYERS      False                  None
# 79    267357         Anonymous       True  Software Engineering
# 1914  238734      Jordy Backes      False                  None
# 175   269043          Alexis D      False                  None
# 473   250947       Chris Field      False          UX/UI Design
# 90    238805  Daniel Schroeder      False       Web Development
# 225   233815          Eugene M      False                  None
# 667   269843    Kay Richardson      False                  None
# 1342  244609           Adriaan      False                  None
# 707   257192   Rafał Bagrowski      False  Software Engineering
# 12    277561         Anonymous       True                  None
# 298   240392     Jorge Carmona      False  Software Engineering
# 54    241082      Jesse Hatton      False  Software Engineering
# 197   239788         Anonymous       True         Bootcamp Prep
# 3     282965     Simba Chikuni      False                  None
#
#       graduatingYear isAlumni                              jobTitle  \
# 370           2021.0    False                        UX/UI Designer
# 79            2020.0    False                     Software Engineer
# 1914          2016.0     True                                  None
# 175           2020.0    False                         Web Developer
# 473           2019.0     True                          Art Director
# 90            2017.0     True  Freelance Musician and Web Developer
# 225           2014.0     True                     Software Engineer
# 667           2020.0    False
# 1342          2018.0     True                                  None
# 707           2018.0    False                                  None
# 12            2020.0    False                     Software Engineer
# 298           2017.0     True                  Full-Stack Developer
# 54            2018.0     True                                  None
# 197           2017.0     True                          C# developer
# 3             2021.0     True                   Business Consultant
#
#                                                 tagline  \
# 370             I was on the fence reading these too...
# 79    Hands-down THE best educational experience of ...
# 1914                                         Fulfilling
# 175   I particularly appreciated the quality of the ...
# 473                         UX: Research &amp; Strategy
# 90    One of the best education decisions I've made,...
# 225                             You get what you put in
# 667                                It's a game changer.
# 1342                            Intro to Programming ND
# 707   Results exceeding all expectations - Udacity F...
# 12                                            FANTASTIC
# 298       Coding Dojo prepared me for my career change.
# 54             All good things come to an end..."sigh!"
# 197                                 Awesome prep course
# 3                                Well structured course
#
#                                                    body  \
# 370   <span class="truncatable"><p></p><p>I just com...
# 79    <span class="truncatable"><p>I have done a lot...
# 1914  <span class="truncatable"><p>Before joining Le...
# 175   <span class="truncatable"><p>I have been a com...
# 473   <span class="truncatable"><p>This course excee...
# 90    <span class="truncatable"><p>I jumped into the...
# 225   <p>Made some great friends, got a job, worked ...
# 667   <span class="truncatable"><p>This workshop is ...
# 1342  <span class="truncatable"><p>The program takes...
# 707   <span class="truncatable"><p>Front End Web Dev...
# 12    <span class="truncatable"><p></p><p>I just lov...
# 298   <span class="truncatable"><p>I always had a pa...
# 54    <span class="truncatable"><p>The Code Immersio...
# 197   <span class="truncatable"><p>Hack Reactor's cu...
# 3     <span class="truncatable"><p></p><p>Thee cours...
#
#                                                 rawBody  ...   queryDate  \
# 370   <p>I just compleated the Springboard course an...  ...  2021-04-05
# 79    I have done a lot of educational programs, but...  ...  2020-08-10
# 1914  Before joining Le Wagon I was student in Amste...  ...  2017-10-12
# 175   I have been a communication manager for severa...  ...  2020-10-02
# 473   This course exceeded my expectations. While I ...  ...  2019-05-06
# 90    I jumped into the Tech Talent South Code Immer...  ...  2017-10-11
# 225   Made some great friends, got a job, worked my ...  ...  2017-01-13
# 667   This workshop is it! When starting it, I didn'...  ...  2020-10-29
# 1342  The program takes you from the very basic to s...  ...  2018-08-20
# 707   Front End Web Developer Nanodegree prepared me...  ...  2019-10-11
# 12    <p>I just love the fact that I get to write co...  ...  2021-05-27
# 298   I always had a passion for technology since co...  ...  2018-11-08
# 54    The Code Immersion course definitely met expec...  ...  2018-03-19
# 197   Hack Reactor's curriculum is just amazing! You...  ...  2018-06-05
# 3     <p>Thee course was very well designed. All the...  ...  2021-11-02
#
#                                                 program             user  \
# 370                           UI/UX Design Career Track  {'image': None}
# 79                       Software Engineering Immersive  {'image': None}
# 1914                  FullStack program - 35+ locations  {'image': None}
# 175                  Fullstack JavaScript Web Developer  {'image': None}
# 473                              UX Research & Strategy  {'image': None}
# 90                     Full-Time Code Immersion Program  {'image': None}
# 225                                                None  {'image': None}
# 667                            SheCodes Online Workshop  {'image': None}
# 1342                                               None  {'image': None}
# 707                             Front End Web Developer  {'image': None}
# 12                                                 None  {'image': None}
# 298   Onsite Software Development Immersive Bootcamp...  {'image': None}
# 54                     Full-Time Code Immersion Program  {'image': None}
# 197                                       Bootcamp Prep  {'image': None}
# 3                                                        {'image': None}
#
#      overallScore comments overall curriculum jobSupport  \
# 370           4.7       []     5.0        5.0        4.0
# 79            5.0       []     5.0        5.0        5.0
# 1914          5.0       []     5.0        5.0        5.0
# 175           5.0       []     5.0        5.0        5.0
# 473           5.0       []     5.0        5.0        NaN
# 90            5.0       []     5.0        5.0        5.0
# 225           4.7       []     5.0        5.0        4.0
# 667           5.0       []     5.0        5.0        5.0
# 1342          5.0       []     5.0        5.0        NaN
# 707           5.0       []     5.0        5.0        5.0
# 12            5.0       []     5.0        5.0        5.0
# 298           5.0       []     5.0        5.0        5.0
# 54            4.0       []     4.0        4.0        NaN
# 197           5.0       []     5.0        5.0        NaN
# 3             5.0       []     5.0        5.0        NaN
#
#                                             review_body             school
# 370   I just compleated the Springboard course and h...        springboard
# 79    I have done a lot of educational programs, but...       hack-reactor
# 1914  Before joining Le Wagon I was student in Amste...           le-wagon
# 175   I have been a communication manager for severa...         la-capsule
# 473   This course exceeded my expectations. While I ...          designlab
# 90    I jumped into the Tech Talent South Code Immer...  tech-talent-south
# 225   Made some great friends, got a job, worked my ...    flatiron-school
# 667   This workshop is it! When starting it, I didn'...           shecodes
# 1342  The program takes you from the very basic to s...            udacity
# 707   Front End Web Developer Nanodegree prepared me...            udacity
# 12    I just love the fact that I get to write code ...          dataquest
# 298   I always had a passion for technology since co...        coding-dojo
# 54    The Code Immersion course definitely met expec...  tech-talent-south
# 197   Hack Reactor's curriculum is just amazing! You...       hack-reactor
# 3     Thee course was very well designed. All the kn...        simplilearn
#
# [15 rows x 21 columns]

# %%
# Review types for the columns
#We can see that some columns should be numbers float/int and they arent 
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear     float64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore        object
# comments            object
# overall             object
# curriculum          object
# jobSupport          object
# review_body         object
# school              object
# dtype: object

# %%
#Validation for empty values
comments.isnull().sum()
# Out:
# id                     0
# name                   0
# anonymous              0
# hostProgramName    13368
# graduatingYear       235
# isAlumni              17
# jobTitle            9285
# tagline                3
# body                   0
# rawBody                0
# createdAt              0
# queryDate              0
# program             3663
# user                   0
# overallScore          48
# comments               0
# overall               50
# curriculum           878
# jobSupport          3165
# review_body            0
# school                 0
# dtype: int64

# %%
#There are empty spaces
comments[comments['overallScore'].isnull()].count()
# Out:
# id                 48
# name               48
# anonymous          48
# hostProgramName    11
# graduatingYear     41
# isAlumni           48
# jobTitle            7
# tagline            47
# body               48
# rawBody            48
# createdAt          48
# queryDate          48
# program            24
# user               48
# overallScore        0
# comments           48
# overall             0
# curriculum          0
# jobSupport          0
# review_body        48
# school             48
# dtype: int64

# %%
comments['overallScore'].unique()
# Out:
# array(['5.0', '3.7', '2.0', '4.7', '4.3', '3.0', '4.0', '4.5', '3.5',
#        '3.3', '2.3', '1.7', '1.5', '1.0', '2.7', '1.3', '2.5', None,
#        '4.2', '4.8', '3.2'], dtype=object)

# %%
comments['overall'].unique()
# Out:
# array(['5.0', '2.0', '4.0', '3.0', '1.0', nan, '4.5', '3.5'], dtype=object)

# %%
comments['overallScore'].value_counts()
# Out:
# 5.0    15811
# 4.7     2944
# 4.3     1667
# 4.0     1490
# 3.7      567
# 4.5      264
# 1.0      230
# 3.3      226
# 3.0      221
# 2.0      116
# 2.7       92
# 2.3       80
# 1.7       73
# 1.3       68
# 3.5       34
# 2.5       16
# 1.5       15
# 4.2        2
# 4.8        1
# 3.2        1
# Name: overallScore, dtype: int64

# %%
comments['overall'].value_counts()
# Out:
# 5.0    20196
# 4.0     2789
# 3.0      359
# 1.0      348
# 2.0      218
# 4.5        5
# 3.5        1
# Name: overall, dtype: int64

# %%
comments['comments'].isnull().sum()
# Out:
# 0

# %%
comments['curriculum'].unique()
# Out:
# array(['5.0', '2.0', '4.0', '3.0', nan, '1.0', '2.5'], dtype=object)

# %%
comments['jobSupport'].unique()
# Out:
# array(['5.0', '1.0', '2.0', '3.0', '4.0', nan], dtype=object)

# %% [markdown]
# ## Cleanning proccess for all the tables

# %% [markdown]
# ### Table comments

# %%
comments[['overallScore','overall','curriculum','jobSupport']] = comments[['overallScore','overall','curriculum','jobSupport']].astype('float64')

# %%
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear     float64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore       float64
# comments            object
# overall            float64
# curriculum         float64
# jobSupport         float64
# review_body         object
# school              object
# dtype: object

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022., 2021., 2020., 2019., 2018., 2016., 2017., 2015., 2014.,
#        2012.,   nan, 2011., 2013., 2010.])

# %%
#For empty/nan we will replace it with 0 , it Could be another Value like No Date
comments['graduatingYear'] = comments['graduatingYear'].fillna(0)

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022., 2021., 2020., 2019., 2018., 2016., 2017., 2015., 2014.,
#        2012.,    0., 2011., 2013., 2010.])

# %%
#pd.to_datetime(comments['graduatingYear'])
#comments['graduatingYear'].dt.strftime('%d.%m.%Y')

comments['graduatingYear'] = comments['graduatingYear'].astype('int64')

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2016, 2017, 2015, 2014, 2012,    0,
#        2011, 2013, 2010])

# %%
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear       int64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore       float64
# comments            object
# overall            float64
# curriculum         float64
# jobSupport         float64
# review_body         object
# school              object
# dtype: object

# %%
#Changing column to datetime type
comments['queryDate'] = pd.to_datetime(comments['queryDate'])
#comments['queryDate'].dt.strftime('%d.%m.%Y')
comments['queryDate']
# Out:
# 0     2022-04-01
# 1     2022-03-24
# 2     2022-03-23
# 3     2022-03-17
# 4     2022-03-17
#          ...
# 181   2017-11-28
# 182   2017-10-25
# 183   2017-10-19
# 184   2017-09-13
# 185   2017-08-03
# Name: queryDate, Length: 23966, dtype: datetime64[ns]

# %%
#Changing column to datetime type
comments['createdAt'] = pd.to_datetime(comments['createdAt'])
#comments['queryDate'].dt.strftime('%d.%m.%Y')
comments['createdAt']
# Out:
# 0     2022-04-01
# 1     2022-03-24
# 2     2022-03-23
# 3     2022-03-17
# 4     2022-03-17
#          ...
# 181   2017-11-28
# 182   2017-10-25
# 183   2017-10-19
# 184   2017-09-13
# 185   2017-08-03
# Name: createdAt, Length: 23966, dtype: datetime64[ns]

# %%
comments.dtypes
# Out:
# id                          int64
# name                       object
# anonymous                    bool
# hostProgramName            object
# graduatingYear              int64
# isAlumni                   object
# jobTitle                   object
# tagline                    object
# body                       object
# rawBody                    object
# createdAt          datetime64[ns]
# queryDate          datetime64[ns]
# program                    object
# user                       object
# overallScore              float64
# comments                   object
# overall                   float64
# curriculum                float64
# jobSupport                float64
# review_body                object
# school                     object
# dtype: object

# %%
comments.sample(3)
# Out:
#          id                  name  anonymous       hostProgramName  \
# 544  270192           Anshul Vyas      False                  None
# 184  266069    David Poh Wei Boon      False          Data Science
# 75   247362  Christopher Bücklein      False  Software Engineering
#
#      graduatingYear isAlumni               jobTitle  \
# 544            2020    False
# 184            2020     True
# 75             2018     True  Sr. Marketing Manager
#
#                                                tagline  \
# 544  Springboard || Best professional Data Science ...
# 184                                    Hackwagon DS101
# 75                  Why I'd always go back there again
#
#                                                   body  \
# 544  <span class="truncatable"><p>I was looking for...
# 184  <span class="truncatable"><p>Hackwagon DS101 h...
# 75   <span class="truncatable"><p>I just completed ...
#
#                                                rawBody  ...  queryDate  \
# 544  I was looking for a professional course on Dat...  ... 2020-11-10
# 184  Hackwagon DS101 has allowed me to learn the fu...  ... 2020-07-03
# 75   I just completed my course a month ago and I w...  ... 2019-01-26
#
#                             program             user overallScore  comments  \
# 544       Data Science Career Track  {'image': None}          5.0        []
# 184                    Data Science  {'image': None}          4.7        []
# 75   Software Engineering Immersive  {'image': None}          5.0        []
#
#     overall  curriculum  jobSupport  \
# 544     5.0         5.0         5.0
# 184     5.0         5.0         4.0
# 75      5.0         5.0         5.0
#
#                                            review_body             school
# 544  I was looking for a professional course on Dat...        springboard
# 184  Hackwagon DS101 has allowed me to learn the fu...  hackwagon-academy
# 75   I just completed my course a month ago and I w...          codeworks
#
# [3 rows x 21 columns]

# %%
#Not usefull columns
# user
comments['user'].sample(4)
# Out:
# 350    {'image': None}
# 381    {'image': None}
# 260    {'image': None}
# 578    {'image': None}
# Name: user, dtype: object

# %%
#Already droped,
#comments.drop(['user'],axis=1,inplace=True)

# %%
comments.head()
# Out:
#        id                  name  anonymous hostProgramName  graduatingYear  \
# 0  287305  Javier Leyva Seiglie      False            None            2022
# 1  287077         Oswaldo Salas      False            None            2021
# 2  287024         Oswaldo Salas      False            None            2021
# 3  286880       Aaron Arismendi      False            None            2021
# 4  286878          Octavio Lara      False            None            2021
#
#   isAlumni                  jobTitle  \
# 0    False  Full Stack web developer
# 1    False
# 2    False
# 3    False  Desarrollador Full Stack
# 4    False         Software engineer
#
#                                      tagline  \
# 0          On a simple word, the actual best
# 1  Obtener mucho conocimiento sin frustrarte
# 2  Obtener mucho conocimiento sin frustrarte
# 3                      Una experiencia única
# 4                    A fulfilling experience
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>This is a ...
# 1  <span class="truncatable"><p></p><p>Me gusto m...
# 2  <span class="truncatable"><p></p><p>Particular...
# 3  <span class="truncatable"><p></p><p>No sabía n...
# 4  <span class="truncatable"><p></p><p>I'd say th...
#
#                                              rawBody  ...  queryDate  \
# 0  <p>This is a beast! The best! I attain the ful...  ... 2022-04-01
# 1  <p>Me gusto mucho la din&aacute;mica para ir s...  ... 2022-03-24
# 2  <p>Particularmente creo que el programa de ent...  ... 2022-03-23
# 3  <p>No sab&iacute;a nada a cerca de programaci&...  ... 2022-03-17
# 4  <p>I&#39;d say the main pro would be the commu...  ... 2022-03-17
#
#                                      program             user overallScore  \
# 0            Full Stack Software Development  {'image': None}          5.0
# 1            Full Stack Software Development  {'image': None}          5.0
# 2            Full Stack Software Development  {'image': None}          3.7
# 3            Full Stack Software Development  {'image': None}          5.0
# 4  Full Stack Software Development Part Time  {'image': None}          5.0
#
#    comments overall  curriculum  jobSupport  \
# 0        []     5.0         5.0         5.0
# 1        []     5.0         5.0         5.0
# 2        []     5.0         5.0         1.0
# 3        []     5.0         5.0         5.0
# 4        []     5.0         5.0         5.0
#
#                                          review_body          school
# 0  This is a beast! The best! I attain the full s...  4geeks-academy
# 1  Me gusto mucho la dinámica para ir superando c...  4geeks-academy
# 2  Particularmente creo que el programa de entren...  4geeks-academy
# 3  No sabía nada a cerca de programación hasta qu...  4geeks-academy
# 4  I'd say the main pro would be the community. T...  4geeks-academy
#
# [5 rows x 21 columns]

# %%
#Adjust Text eliminaring <p>
comments['rawBody'] = comments['rawBody'].str.replace('<p>','')
comments['rawBody']
#= comments['rawBody']
# Out:
# 0      This is a beast! The best! I attain the full s...
# 1      Me gusto mucho la din&aacute;mica para ir supe...
# 2      Particularmente creo que el programa de entren...
# 3      No sab&iacute;a nada a cerca de programaci&oac...
# 4      I&#39;d say the main pro would be the communit...
#                              ...
# 181    You never know how you can improve if you don'...
# 182    This course has provided me with the right too...
# 183    Nice bootcamp for people to learn who to codin...
# 184    Everything I learned was broad enough to be re...
# 185    Accelerate was a good choice for me because I ...
# Name: rawBody, Length: 23966, dtype: object

# %%
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p></p><p>','')
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p>','')
comments['body'] = comments['body'].str.replace('<p>','')
badges['description'] = badges['description'].str.replace('</p>','')
comments['body'].sample(6)
# Out:
# 551     It introduced me to the world of programming w...
# 1267    The projects Udacity offers are, in general, a...
# 391     The UX Foundations Course is an excellent, int...
# 111     The class and group is centered around agile p...
# 283     I am a graphic designer and I always wanted to...
# 199     Coding Dojo gave me direction when I was absol...
# Name: body, dtype: object

# %%
comments.sample(5)
# Out:
#          id                    name  anonymous hostProgramName  \
# 23   262288               Anonymous       True    Data Science
# 744  238866  Santiago Becerra Conti      False    UX/UI Design
# 259  280027           Allyson Varga      False            None
# 863  256974                   Mitch      False            None
# 148  242628          Agung Pangestu      False            None
#
#      graduatingYear isAlumni          jobTitle  \
# 23             2020    False
# 744            2018     True  Product Designer
# 259            2021    False       Sales Coach
# 863            2017    False              None
# 148            2018     True              None
#
#                                                tagline  \
# 23                                          Empowering
# 744  Thanks to Ironhack, I was able to be part of t...
# 259        You won't regret learning something new! :)
# 863                         Flexible pace and learning
# 148                    Best Javascript Coding Bootcamp
#
#                                                   body  \
# 23   This class will stretch your mind in ways you ...
# 744  During February and March I've coursed the UX/...
# 259  I LOVED learning the basics of coding in this ...
# 863  I already watch many online courses and Udacit...
# 148  hacktiv8 is great for beginners, I feel myself...
#
#                                                rawBody  ...  queryDate  \
# 23   This class will stretch your mind in ways you ...  ... 2020-02-27
# 744  During February and March I've coursed the UX/...  ... 2018-04-09
# 259  I LOVED learning the basics of coding in this ...  ... 2021-08-05
# 863  I already watch many online courses and Udacit...  ... 2019-10-11
# 148  hacktiv8 is great for beginners, I feel myself...  ... 2018-02-22
#
#                              program             user overallScore  comments  \
# 23                                    {'image': None}          5.0        []
# 744  Full-time UX/UI Design Bootcamp  {'image': None}          5.0        []
# 259                  SheCodes Basics  {'image': None}          5.0        []
# 863                             None  {'image': None}          4.0        []
# 148                             None  {'image': None}          5.0        []
#
#     overall  curriculum  jobSupport  \
# 23      5.0         5.0         5.0
# 744     5.0         5.0         5.0
# 259     5.0         5.0         5.0
# 863     4.0         4.0         4.0
# 148     5.0         5.0         5.0
#
#                                            review_body             school
# 23   This class will stretch your mind in ways you ...  data-science-dojo
# 744  During February and March I've coursed the UX/...           ironhack
# 259  I LOVED learning the basics of coding in this ...           shecodes
# 863  I already watch many online courses and Udacit...            udacity
# 148  hacktiv8 is great for beginners, I feel myself...           hacktiv8
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Table locations

# %%
locations.sample(5)
# Out:
#        id                  description  country.id    country.name  \
# 3   16088            Sao Paulo, Brazil        42.0          Brazil
# 38  17758  Stare Mesto, Czech Republic        31.0  Czech Republic
# 85  16900            Stockholm, Sweden        37.0          Sweden
# 0   16809                Paris, France        38.0          France
# 14  17797             Toulouse, France        38.0          France
#
#    country.abbrev  state.id state.name state.abbrev state.keyword  city.id  \
# 3              BR       NaN        NaN          NaN           NaN  31121.0
# 38             CZ       NaN        NaN          NaN           NaN  31251.0
# 85             SE       NaN        NaN          NaN           NaN  31109.0
# 0              FR       NaN        NaN          NaN           NaN  31136.0
# 14             FR       NaN        NaN          NaN           NaN  31191.0
#
#       city.name city.keyword                        school  school_id
# 3     Sao Paulo    sao-paulo                      ironhack      10828
# 38  Staré Město  stare-mesto  software-development-academy      11030
# 85    Stockholm    stockholm                        nucamp      10923
# 0         Paris        paris              wild-code-school      11169
# 14     Toulouse     toulouse              holberton-school      10796

# %%
locations.dtypes
# Out:
# id                  int64
# description        object
# country.id        float64
# country.name       object
# country.abbrev     object
# state.id          float64
# state.name         object
# state.abbrev       object
# state.keyword      object
# city.id           float64
# city.name          object
# city.keyword       object
# school             object
# school_id           int64
# dtype: object

# %%
#Validation for empty values
locations.isnull().sum()
# Out:
# id                  0
# description         0
# country.id         65
# country.name       65
# country.abbrev     65
# state.id          228
# state.name        228
# state.abbrev      228
# state.keyword     229
# city.id            66
# city.name          66
# city.keyword       66
# school              0
# school_id           0
# dtype: int64

# %%
locations.isna()
# Out:
#        id  description  country.id  country.name  country.abbrev  state.id  \
# 0   False        False       False         False           False     False
# 1   False        False       False         False           False      True
# 2   False        False       False         False           False      True
# 3   False        False       False         False           False      True
# 4   False        False       False         False           False      True
# ..    ...          ...         ...           ...             ...       ...
# 24  False        False        True          True            True     False
# 25  False        False       False         False           False      True
# 0   False        False       False         False           False     False
# 0   False        False       False         False           False      True
# 1   False        False        True          True            True     False
#
#     state.name  state.abbrev  state.keyword  city.id  city.name  city.keyword  \
# 0        False         False          False    False      False         False
# 1         True          True           True    False      False         False
# 2         True          True           True    False      False         False
# 3         True          True           True    False      False         False
# 4         True          True           True    False      False         False
# ..         ...           ...            ...      ...        ...           ...
# 24       False         False          False     True       True          True
# 25        True          True           True    False      False         False
# 0        False         False          False    False      False         False
# 0         True          True           True    False      False         False
# 1        False         False          False     True       True          True
#
#     school  school_id
# 0    False      False
# 1    False      False
# 2    False      False
# 3    False      False
# 4    False      False
# ..     ...        ...
# 24   False      False
# 25   False      False
# 0    False      False
# 0    False      False
# 1    False      False
#
# [506 rows x 14 columns]

# %%
locations[['description','country.id','country.name']].sample(4)
#Empty conuntries is bevause is online
# Out:
#                     description  country.id   country.name
# 2        Kowloon Bay, Hong Kong       144.0      Hong Kong
# 2       Buenos Aires, Argentina        60.0      Argentina
# 0  Cleveland, OH, United States         1.0  United States
# 3               London, England        61.0        England

# %%
locations['description'][locations['country.name'].isnull()].unique()
# Out:
# array(['Online'], dtype=object)

# %% [markdown]
# ### Table courses

# %%
#This one looks ok
courses
# Out:
#                                               courses              school  \
# 0          Ai and Machine Learning Full-Stack Program      4geeks-academy
# 1                     Full Stack Software Development      4geeks-academy
# 2           Full Stack Software Development Part Time      4geeks-academy
# 0   14-Week Intensive && Immersive Full-Stack Prog...  academia-de-codigo
# 0                Actualize Coding Bootcamp: Full-Time           actualize
# ..                                                ...                 ...
# 5       Data Science and Machine Learning (Part-time)          xccelerate
# 6                                  Python for Finance          xccelerate
# 7                                 Python Fundamentals          xccelerate
# 8   Software Engineering Immersive Bootcamp (Full-...          xccelerate
# 9                                           UX Design          xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 2       10492
# 0       10494
# 0       10505
# ..        ...
# 5       11175
# 6       11175
# 7       11175
# 8       11175
# 9       11175
#
# [536 rows x 3 columns]

# %%
courses.dtypes
# Out:
# courses      object
# school       object
# school_id     int64
# dtype: object

# %% [markdown]
# ### Table badges

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0               <p>School offers fully online courses  4geeks-academy
# 1      <p>School offers part-time and evening classes  4geeks-academy
# 0               <p>School offers fully online courses       actualize
# 1      <p>School offers part-time and evening classes       actualize
# 0               <p>School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   <p>School publishes a third-party verified out...         wyncode
# 2      <p>School offers part-time and evening classes         wyncode
# 3                       <p>School accepts the GI Bill         wyncode
# 0               <p>School offers fully online courses      xccelerate
# 1      <p>School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %%
badges.dtypes
# Out:
# name           object
# keyword        object
# description    object
# school         object
# school_id       int64
# dtype: object

# %%
#For cleaning function
#badges['description'] = badges['description'].apply(clean_text_tag(badges['description']))
#badges['description']

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0               <p>School offers fully online courses  4geeks-academy
# 1      <p>School offers part-time and evening classes  4geeks-academy
# 0               <p>School offers fully online courses       actualize
# 1      <p>School offers part-time and evening classes       actualize
# 0               <p>School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   <p>School publishes a third-party verified out...         wyncode
# 2      <p>School offers part-time and evening classes         wyncode
# 3                       <p>School accepts the GI Bill         wyncode
# 0               <p>School offers fully online courses      xccelerate
# 1      <p>School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %%
#Clean text from tags
badges['description'] = badges['description'].str.replace('<span class="truncatable"><p></p><p>','')
badges['description'] = badges['description'].str.replace('<span class="truncatable"><p>','')
badges['description'] = badges['description'].str.replace('<p>','')
badges['description'] = badges['description'].str.replace('</p>','')
badges['description'].sample(6)
# Out:
# 0                   School offers fully online courses
# 0                   School offers fully online courses
# 0                   School offers fully online courses
# 1    School publishes a third-party verified outcom...
# 0                   School offers fully online courses
# 0                   School offers fully online courses
# Name: description, dtype: object

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0                  School offers fully online courses  4geeks-academy
# 1         School offers part-time and evening classes  4geeks-academy
# 0                  School offers fully online courses       actualize
# 1         School offers part-time and evening classes       actualize
# 0                  School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   School publishes a third-party verified outcom...         wyncode
# 2         School offers part-time and evening classes         wyncode
# 3                          School accepts the GI Bill         wyncode
# 0                  School offers fully online courses      xccelerate
# 1         School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %% [markdown]
# ### Table schools

# %%
schools
# Out:
#                                               website  \
# 0                                www.4geeksacademy.co
# 0                        applyto.academiadecodigo.org
# 0   anyonecanlearntocode.com/?utm_source=switchup&...
# 0                                   www.altcademy.com
# 0                                       appacademy.io
# ..                                                ...
# 0                              uxdesigninstitute.com/
# 0                                  www.uxerschool.com
# 0                                  wildcodeschool.com
# 0                                      www.wyncode.co
# 0                                       xccelerate.co
#
#                                           description  \
# 0   <span class="truncatable"><p>4Geeks Academy is...
# 0   <span class="truncatable"><p>Founded in Lisbon...
# 0   <span class="truncatable"><p>Actualize is a co...
# 0   <span class="truncatable"><p>Altcademy is a 10...
# 0   <span class="truncatable"><p>App Academy is a ...
# ..                                                ...
# 0   <span class="truncatable"><p>The UX Design Ins...
# 0   <span class="truncatable"><p>UXER School is an...
# 0   <span class="truncatable"><p>Wild Code School ...
# 0   <span class="truncatable"><p>Wyncode Academy i...
# 0   <span class="truncatable"><p>Xccelerate is a s...
#
#                                               LogoUrl               school  \
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...       4geeks-academy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...   academia-de-codigo
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            actualize
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            altcademy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# ..                                                ...                  ...
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...  ux-design-institute
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          uxer-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...     wild-code-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...              wyncode
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...           xccelerate
#
#     school_id
# 0       10492
# 0       10494
# 0       10505
# 0       10517
# 0       10525
# ..        ...
# 0       11150
# 0       11151
# 0       11169
# 0       11174
# 0       11175
#
# [78 rows x 5 columns]

# %%
schools.dtypes
# Out:
# website        object
# description    object
# LogoUrl        object
# school         object
# school_id       int64
# dtype: object

# %%
#Clean text from tags
schools['description'] = schools['description'].str.replace('<span class="truncatable"><p></p><p>','')
schools['description'] = schools['description'].str.replace('<span class="truncatable"><p>','')
schools['description'] = schools['description'].str.replace('<p>','')
schools['description'] = schools['description'].str.replace('</p>','')
schools['description'].sample(6)
# Out:
# 0    SIT Academy offers 12-week full-time and 22-we...
# 0    Become a highly-skilled Data professional with...
# 0    Evolve Security Academy offers holistic cybers...
# 0    Devmountain is a coding bootcamp and design sc...
# 0    We provide exclusive IT training in South Afri...
# 0    H Academy helps empower individuals to build t...
# Name: description, dtype: object

# %%
schools
# Out:
#                                               website  \
# 0                                www.4geeksacademy.co
# 0                        applyto.academiadecodigo.org
# 0   anyonecanlearntocode.com/?utm_source=switchup&...
# 0                                   www.altcademy.com
# 0                                       appacademy.io
# ..                                                ...
# 0                              uxdesigninstitute.com/
# 0                                  www.uxerschool.com
# 0                                  wildcodeschool.com
# 0                                      www.wyncode.co
# 0                                       xccelerate.co
#
#                                           description  \
# 0   4Geeks Academy is a Coding Bootcamp focused on...
# 0   Founded in Lisbon in 2015, this Portuguese-bor...
# 0   Actualize is a coding bootcamp that values qua...
# 0   Altcademy is a 100% online education institute...
# 0   App Academy is a coding school that offers onl...
# ..                                                ...
# 0   The UX Design Institute offers 6 month, online...
# 0   UXER School is an education startup, specializ...
# 0   Wild Code School offers 5-month web developmen...
# 0   Wyncode Academy is a premier technical educato...
# 0   Xccelerate is a socially-aligned education sta...
#
#                                               LogoUrl               school  \
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...       4geeks-academy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...   academia-de-codigo
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            actualize
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            altcademy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# ..                                                ...                  ...
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...  ux-design-institute
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          uxer-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...     wild-code-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...              wyncode
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...           xccelerate
#
#     school_id
# 0       10492
# 0       10494
# 0       10505
# 0       10517
# 0       10525
# ..        ...
# 0       11150
# 0       11151
# 0       11169
# 0       11174
# 0       11175
#
# [78 rows x 5 columns]

# %%
# Reseting all indexes

comments = comments.reset_index()
locations = locations.reset_index()
badges = badges.reset_index()
schools = schools.reset_index()
courses = courses.reset_index()

# %%
# Dropped columns: "user" and "comments" in comments to avoid problems 

comments.drop(['user','comments'], axis='columns', inplace=True)

# %% [markdown]
# ## Sending dataframes to MySQL

# %%
import mysql.connector
import getpass

saved_password = getpass.getpass()
cnx = mysql.connector.connect(user = 'root', # Specify your user 
                              password = saved_password, 
                              host ='localhost', 
                              database = 'sakila',
                              auth_plugin='mysql_native_password')
# Out:
# ········

# %%
cnx.is_connected()
if cnx.is_connected():
    print("Connection open")
    # do stuff you need to the database
else:
    print("Connection is not successfully open")
# Out:
# Connection open

# %%
cursor = cnx.cursor()

#Create database

def sql_db(db_name):
    query = f"CREATE DATABASE {db_name}"
    print(query)
    use_db = f"USE {db_name}"
    print(use_db)
    cursor.execute(query)
    cursor.execute(use_db)
    return db_name 

#Execute the full process of a query

def sql_action():
    query = input('Please write your query...')
    #cursor.execute(query,multi=True)
    results = cursor.fetchall()
    results_df = pd.DataFrame(results)
    return "Action completed" 

#Finalize SQL process

def sql_close_connection():
    return cnx.commit(), cursor.close(), cnx.close()

# %%
# Creating database - create it as string

db = sql_db("sql_project")
# Out:
# CREATE DATABASE sql_project
# USE sql_project

# %%
# Alchemy setup 

from sqlalchemy import create_engine
import pymysql

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw=saved_password,
                               db=db))

# %%
# Alchemy insert values - having problems when looped
badges.to_sql('badges', con = engine, if_exists = 'replace', chunksize = 1000)
locations.to_sql('locations', con = engine, if_exists = 'replace', chunksize = 1000)
courses.to_sql('courses', con = engine, if_exists = 'replace', chunksize = 1000)
schools.to_sql('schools', con = engine, if_exists = 'replace', chunksize = 1000)
comments.to_sql('comments', con = engine, if_exists = 'replace', chunksize = 1000)

# %%
# Setting primary KEYs with pandas default indexes - locations table has already an id so we would need to rename based on another keyword or keep it as level_0
cursor.execute("ALTER TABLE comments ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE schools ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE locations ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE courses ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE badges ADD PRIMARY KEY (level_0)")
cursor.fetchall()
# Out:
# []
