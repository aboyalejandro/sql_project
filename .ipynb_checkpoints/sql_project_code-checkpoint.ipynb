# %%
#Imports

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests

# %% [markdown]
# # Dictionary with top schools

# %%
schools = {   
'4geeks-academy'  : 10492,
'academia-de-codigo'  : 10494,
'actualize'  : 10505,
'altcademy'  : 10517,
'app-academy'  : 10525,
'bloomtech'  : 10854,
'brainstation'  : 10571,
'careerfoundry'  : 10581,
'careerist'  : 11280,
'claim-academy'  : 10589,
'clarusway'  : 11539,
'code-fellows'  : 10614,
'code-institute'  : 10619,
'codesmith'  : 10643,
'codeworks'  : 10650,
'coding-bootcamp-praha'  : 10658,
'coding-dojo'  : 10659,
'coding-temple'  : 10664,
#'correlation-one'  : 11528,
'datacamp'  : 10682,
'dataquest'  : 10683,
'data-science-dojo'  : 10685,
'datascientest'  : 11232,
'designlab'  : 10697,
'devcodecamp'  : 10703,
'developers-institute'  : 10705,
'devmountain'  : 10710,
'digitalcrafts'  : 10719,
'epicodus'  : 10739,
'evolve-security-academy'  : 10743,
'flatiron-school'  : 10748,
'general-assembly'  : 10761,
'greyatom-school-of-data-science'  : 10776,
'h-academy'  : 11518,
'hack-reactor'  : 10788,
'hacktiv8'  : 10791,
'hackwagon-academy'  : 10792,
'heicoders-academy'  : 11287,
'holberton-school'  : 10796,
'hyperiondev'  : 10801,
'ironhack'  : 10828,
'jedha'  : 10837,
'juno-college-of-technology'  : 10787,
'kenzie-academy'  : 10843,
'knowledgehut'  : 10846,
'la-capsule'  : 10853,
'learningfuze'  : 10862,
'le-wagon'  : 10868,
'lighthouse-labs'  : 10869,
'makers-academy'  : 10874,
'microverse'  : 10888,
'neoland'  : 10906,
'nucamp'  : 10923,
'nyc-data-science-academy'  : 10925,
'practicum'  : 11225,
'product-gym'  : 10959,
'product-school'  : 10960,
'react-graphql-academy'  : 10972,
'rmotr'  : 10987,
'rocket-academy'  : 11483,
'school-of-it'  : 11006,
'shecodes'  : 11014,
'simplilearn'  : 11016,
'sit-academy'  : 10965,
'skillcrush'  : 11020,
'software-development-academy'  : 11030,
'springboard'  : 11035,
'startup-institute'  : 11042,
'tech-elevator'  : 11056,
'tech-talent-south'  : 11059,
'the-job-hackers'  : 11085,
'the-tech-academy'  : 11091,
'thinkful'  : 11098,
'udacity'  : 11118,
'ux-design-institute'  : 11150,
'uxer-school'  : 11151,
'wild-code-school'  : 11169,
'wyncode'  : 11174,
'xccelerate'  : 11175,

}

# %% [markdown]
# # Functions

# %%
#Function for Scraping 
def get_comments_school(school):
    #This function extracts all the 
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
#get_comments_school('wyncode')

# %%
"""comments = [get_comments_school(school) for school in schools.keys()]
print("Finished collecting comments.")
comments = pd.concat(comments)"""

# %%
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# 4geeks-academy
# academia-de-codigo
# actualize
# altcademy
# app-academy
# bloomtech
# brainstation
# careerfoundry
# careerist
# claim-academy
# clarusway
# code-fellows
# code-institute
# codesmith
# codeworks
# coding-bootcamp-praha
# coding-dojo
# coding-temple
# datacamp
# dataquest
# data-science-dojo
# datascientest
# designlab
# devcodecamp
# developers-institute
# devmountain
# digitalcrafts
# epicodus
# evolve-security-academy
# flatiron-school
# general-assembly
# greyatom-school-of-data-science
# h-academy
# hack-reactor
# hacktiv8
# hackwagon-academy
# heicoders-academy
# holberton-school
# hyperiondev
# ironhack
# jedha
# juno-college-of-technology
# kenzie-academy
# knowledgehut
# la-capsule
# learningfuze
# le-wagon
# lighthouse-labs
# makers-academy
# microverse
# neoland
# nucamp
# nyc-data-science-academy
# practicum
# product-gym
# product-school
# react-graphql-academy
# rmotr
# rocket-academy
# school-of-it
# shecodes
# simplilearn
# sit-academy
# skillcrush
# software-development-academy
# springboard
# startup-institute
# tech-elevator
# tech-talent-south
# the-job-hackers
# the-tech-academy
# thinkful
# udacity
# ux-design-institute
# uxer-school
# wild-code-school
# wyncode
# xccelerate

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

# %%
locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# 4geeks-academy
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_2332/4240401434.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# academia-de-codigo
# actualize
# altcademy
# app-academy
# bloomtech
# brainstation
# careerfoundry
# careerist
# claim-academy
# clarusway
# code-fellows
# code-institute
# codesmith
# codeworks
# coding-bootcamp-praha
# coding-dojo
# coding-temple
# datacamp
# dataquest
# data-science-dojo
# datascientest
# designlab
# devcodecamp
# developers-institute
# devmountain
# digitalcrafts
# epicodus
# evolve-security-academy
# flatiron-school
# general-assembly
# greyatom-school-of-data-science
# h-academy
# hack-reactor
# hacktiv8
# hackwagon-academy
# heicoders-academy
# holberton-school
# hyperiondev
# ironhack
# jedha
# juno-college-of-technology
# kenzie-academy
# knowledgehut
# la-capsule
# learningfuze
# le-wagon
# lighthouse-labs
# makers-academy
# microverse
# neoland
# nucamp
# nyc-data-science-academy
# practicum
# product-gym
# product-school
# react-graphql-academy
# rmotr
# rocket-academy
# school-of-it
# shecodes
# simplilearn
# sit-academy
# skillcrush
# software-development-academy
# springboard
# startup-institute
# tech-elevator
# tech-talent-south
# the-job-hackers
# the-tech-academy
# thinkful
# udacity
# ux-design-institute
# uxer-school
# wild-code-school
# wyncode
# xccelerate

# %%
#Dataframes creation 
locations = pd.concat(locations_list)
courses = pd.concat(courses_list)
badges = pd.concat(badges_list)
schools = pd.concat(schools_list)

# %%
#Function to clean
def clean_text_tag(col):
    col.str.replace('<span class="truncatable"><p></p><p>','')
    col.str.replace('<span class="truncatable"><p>','')
    col.str.replace('<p>','')
    col.str.replace('</p>','')

# %% [markdown]
# # Dataframes exploration

# %%
# Tables / dataframes
    # comments
    # locations
    # courses
    # badges
    # schools

# %%
#Sizes for all
print('Comments',comments.shape)
print('locations',locations.shape)
print('courses',courses.shape)
print('badges',badges.shape)
print('schools',schools.shape)
# Out:
# Comments (23981, 21)
# locations (506, 14)
# courses (536, 3)
# badges (163, 5)
# schools (78, 5)

# %% [markdown]
# ### We start exploring for cleaning process by table/dataframe

# %%
#we start with comments
comments.describe()
# Out:
#                   id  graduatingYear
# count   24005.000000    23770.000000
# mean   257639.691064     2018.818006
# std     16315.662118        1.839776
# min    231508.000000     2010.000000
# 25%    243274.000000     2018.000000
# 50%    257251.000000     2019.000000
# 75%    271403.000000     2020.000000
# max    287431.000000     2022.000000

# %%
comments.sample(15)
# Out:
#          id                name  anonymous       hostProgramName  \
# 335  241732        David Conner      False                  None
# 719  243884           Anonymous       True        Data Analytics
# 123  241347    Steven Rodriguez      False       Web Development
# 985  256038        Théo Rouland      False  Software Engineering
# 123  235767       Angela Barnes      False                  None
# 91   261179        Stanley Hall      False  Software Engineering
# 84   253682  Juliann Talkington      False  Software Engineering
# 31   265039         Omar Jabara      False    Product Management
# 156  245851           Anonymous       True  Software Engineering
# 322  266608      Rafael Chapine      False  Software Engineering
# 117  253305       Michael Galas      False  Software Engineering
# 467  262350    Griffin Schulert      False                  None
# 141  246800       Luís Ferreira      False  Software Engineering
# 150  241865           Agustinus      False                  None
# 101  258806              Alex J      False          UX/UI Design
#
#      graduatingYear isAlumni                      jobTitle  \
# 335          2016.0     True                          None
# 719          2017.0     True         Accounting Technician
# 123          2017.0     True                          None
# 985          2019.0     True                          None
# 123          2017.0     True        Database Administrator
# 91           2019.0    False                          None
# 84           2019.0     True                          None
# 31           2020.0    False
# 156          2018.0     True                          None
# 322          2020.0    False  Web development fundamentals
# 117          2018.0     True                          None
# 467          2020.0     True
# 141          2017.0     True                          None
# 150          2017.0     True                          None
# 101          2019.0    False                          None
#
#                                                tagline  \
# 335                          Genuine Program and Staff
# 719                           Data Analytics Fall 2017
# 123                      From A Beginner's Perspective
# 985                           Life-changing experience
# 123                         Enjoyed the overall course
# 91   this course is really good compared to some of...
# 84                                       Great program
# 31   Product School - Product Management certification
# 156                                    Time not wasted
# 322                               Great code boot camp
# 117                       Great C# &amp; .NET Bootcamp
# 467  Nucamp Web Development Fundamentals - Learn to...
# 141                             Best experience ever!!
# 150                   Best courses to learn Javascript
# 101                                      Well worth it
#
#                                                   body  \
# 335  <span class="truncatable"><p>I've checked out ...
# 719  <span class="truncatable"><p>The pros of takin...
# 123  <span class="truncatable"><p>The first time I ...
# 985  <span class="truncatable"><p>As a business sch...
# 123  <span class="truncatable"><p>I enjoyed the cou...
# 91   <span class="truncatable"><p>Excellent trainin...
# 84   <span class="truncatable"><p>​Whether you are ...
# 31   <span class="truncatable"><p>I recently comple...
# 156  <span class="truncatable"><p>If you are lookin...
# 322  <span class="truncatable"><p>Awesome flow, eve...
# 117  <p>I took the C# &amp; .NET Framework and lear...
# 467  <span class="truncatable"><p></p><p>The Nucamp...
# 141  <span class="truncatable"><p> provided me the ...
# 150  <p>Benar benar jadi siap kerja. Tekanan untuk ...
# 101  <span class="truncatable"><p>Really enjoyed th...
#
#                                                rawBody  ...   queryDate  \
# 335  I've checked out nearly all of the coding boot...  ...  2018-01-16
# 719  The pros of taking the 10 week Data Analytics ...  ...  2018-02-21
# 123  The first time I had ever attempted to code wa...  ...  2017-06-06
# 985  As a business school student and young product...  ...  2019-10-03
# 123  I enjoyed the course as a whole. The teachers ...  ...  2017-05-26
# 91   Excellent training to get a grip on front end ...  ...  2020-01-20
# 84   ​Whether you are looking for technical trainin...  ...  2019-08-25
# 31   I recently completed the 5 day intensive Produ...  ...  2020-05-28
# 156  If you are looking for a coding bootcamp to st...  ...  2018-12-10
# 322  Awesome flow, everything is linked and organiz...  ...  2020-07-20
# 117  I took the C# & .NET Framework and learned a l...  ...  2019-07-21
# 467  <p>The Nucamp intro to HTML, CSS and Javascrip...  ...  2020-02-29
# 141  <Academia de Código_> provided me the best exp...  ...  2019-03-01
# 150  Benar benar jadi siap kerja. Tekanan untuk ter...  ...  2018-01-22
# 101  Really enjoyed this course, particularly havin...  ...  2019-11-15
#
#                                                program             user  \
# 335                                               None  {'image': None}
# 719                                     Data Analytics  {'image': None}
# 123                                               None  {'image': None}
# 985                                               None  {'image': None}
# 123                                               None  {'image': None}
# 91                                                      {'image': None}
# 84                                                None  {'image': None}
# 31                      Product Management Certificate  {'image': None}
# 156                           Full Stack Flex - Online  {'image': None}
# 322                       Web Development Fundamentals  {'image': None}
# 117                    C# and .NET Framework Boot Camp  {'image': None}
# 467                                                     {'image': None}
# 141  14-Week Intensive && Immersive Full-Stack Prog...  {'image': None}
# 150                                               None  {'image': None}
# 101                  Professional Diploma in UX Design  {'image': None}
#
#     overallScore comments overall curriculum jobSupport  \
# 335          5.0       []     5.0        5.0        5.0
# 719          4.0       []     4.0        4.0        NaN
# 123          5.0       []     5.0        5.0        5.0
# 985          5.0       []     5.0        5.0        5.0
# 123          3.7       []     4.0        4.0        3.0
# 91           4.7       []     5.0        4.0        5.0
# 84           5.0       []     5.0        5.0        5.0
# 31           5.0       []     5.0        5.0        5.0
# 156          4.3       []     5.0        4.0        4.0
# 322          4.7       []     5.0        4.0        5.0
# 117          5.0       []     5.0        5.0        5.0
# 467          4.7       []     5.0        4.0        5.0
# 141          5.0       []     5.0        5.0        5.0
# 150          4.7       []     5.0        4.0        5.0
# 101          5.0       []     5.0        5.0        5.0
#
#                                            review_body               school
# 335  I've checked out nearly all of the coding boot...             thinkful
# 719  The pros of taking the 10 week Data Analytics ...     general-assembly
# 123  The first time I had ever attempted to code wa...        digitalcrafts
# 985  As a business school student and young product...             le-wagon
# 123  I enjoyed the course as a whole. The teachers ...            bloomtech
# 91   Excellent training to get a grip on front end ...            practicum
# 84   ​Whether you are looking for technical trainin...         learningfuze
# 31   I recently completed the 5 day intensive Produ...       product-school
# 156  If you are looking for a coding bootcamp to st...             thinkful
# 322  Awesome flow, everything is linked and organiz...               nucamp
# 117  I took the C# &amp; .NET Framework and learned...     the-tech-academy
# 467  The Nucamp intro to HTML, CSS and Javascript c...               nucamp
# 141   provided me the best experience I ever had in...   academia-de-codigo
# 150  Benar benar jadi siap kerja. Tekanan untuk ter...             hacktiv8
# 101  Really enjoyed this course, particularly havin...  ux-design-institute
#
# [15 rows x 21 columns]

# %%
# Review types for the columns
#We can see that some columns should be numbers float/int and they arent 
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear     float64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore        object
# comments            object
# overall             object
# curriculum          object
# jobSupport          object
# review_body         object
# school              object
# dtype: object

# %%
#Validation for empty values
comments.isnull().sum()
# Out:
# id                     0
# name                   0
# anonymous              0
# hostProgramName    13407
# graduatingYear       235
# isAlumni              17
# jobTitle            9285
# tagline                3
# body                   0
# rawBody                0
# createdAt              0
# queryDate              0
# program             3665
# user                   0
# overallScore          48
# comments               0
# overall               50
# curriculum           878
# jobSupport          3179
# review_body            0
# school                 0
# dtype: int64

# %%
#There are empty spaces
comments[comments['overallScore'].isnull()].count()
# Out:
# id                 48
# name               48
# anonymous          48
# hostProgramName    11
# graduatingYear     41
# isAlumni           48
# jobTitle            7
# tagline            47
# body               48
# rawBody            48
# createdAt          48
# queryDate          48
# program            24
# user               48
# overallScore        0
# comments           48
# overall             0
# curriculum          0
# jobSupport          0
# review_body        48
# school             48
# dtype: int64

# %%
comments['overallScore'].unique()
# Out:
# array(['5.0', '3.7', '2.0', '4.7', '4.3', '3.0', '4.0', '4.5', '3.5',
#        '3.3', '2.3', '1.7', '1.5', '1.0', '2.7', '1.3', '2.5', None,
#        '4.2', '4.8', '3.2'], dtype=object)

# %%
comments['overall'].unique()
# Out:
# array(['5.0', '2.0', '4.0', '3.0', '1.0', nan, '4.5', '3.5'], dtype=object)

# %%
comments['overallScore'].value_counts()
# Out:
# 5.0    15841
# 4.7     2947
# 4.3     1670
# 4.0     1492
# 3.7      568
# 4.5      264
# 1.0      230
# 3.3      226
# 3.0      221
# 2.0      116
# 2.7       92
# 2.3       80
# 1.7       73
# 1.3       68
# 3.5       34
# 2.5       16
# 1.5       15
# 4.2        2
# 4.8        1
# 3.2        1
# Name: overallScore, dtype: int64

# %%
comments['overall'].value_counts()
# Out:
# 5.0    20231
# 4.0     2793
# 3.0      359
# 1.0      348
# 2.0      218
# 4.5        5
# 3.5        1
# Name: overall, dtype: int64

# %%
comments['comments'].isnull().sum()
# Out:
# 0

# %%
comments['curriculum'].unique()
# Out:
# array(['5.0', '2.0', '4.0', '3.0', nan, '1.0', '2.5'], dtype=object)

# %%
comments['jobSupport'].unique()
# Out:
# array(['5.0', '1.0', '2.0', '3.0', '4.0', nan], dtype=object)

# %% [markdown]
# ## Cleanning proccess for all the tables

# %% [markdown]
# ### Table comments

# %%
comments[['overallScore','overall','curriculum','jobSupport']] = comments[['overallScore','overall','curriculum','jobSupport']].astype('float64')

# %%
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear     float64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore       float64
# comments            object
# overall            float64
# curriculum         float64
# jobSupport         float64
# review_body         object
# school              object
# dtype: object

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022., 2021., 2020., 2019., 2018., 2016., 2017., 2015., 2014.,
#        2012.,   nan, 2011., 2013., 2010.])

# %%
#For empty/nan we will replace it with 0 , it Could be another Value like No Date
comments['graduatingYear'] = comments['graduatingYear'].fillna(0)

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022., 2021., 2020., 2019., 2018., 2016., 2017., 2015., 2014.,
#        2012.,    0., 2011., 2013., 2010.])

# %%
#pd.to_datetime(comments['graduatingYear'])
#comments['graduatingYear'].dt.strftime('%d.%m.%Y')

comments['graduatingYear'] = comments['graduatingYear'].astype('int64')

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2016, 2017, 2015, 2014, 2012,    0,
#        2011, 2013, 2010], dtype=int64)

# %%
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear       int64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore       float64
# comments            object
# overall            float64
# curriculum         float64
# jobSupport         float64
# review_body         object
# school              object
# dtype: object

# %%
#Changing column to datetime type
comments['queryDate'] = pd.to_datetime(comments['queryDate'])
#comments['queryDate'].dt.strftime('%d.%m.%Y')
comments['queryDate']
# Out:
# 0     2022-04-01
# 1     2022-03-24
# 2     2022-03-23
# 3     2022-03-17
# 4     2022-03-17
#          ...
# 182   2017-11-28
# 183   2017-10-25
# 184   2017-10-19
# 185   2017-09-13
# 186   2017-08-03
# Name: queryDate, Length: 24005, dtype: datetime64[ns]

# %%
#Changing column to datetime type
comments['createdAt'] = pd.to_datetime(comments['createdAt'])
#comments['queryDate'].dt.strftime('%d.%m.%Y')
comments['createdAt']
# Out:
# 0     2022-04-01
# 1     2022-03-24
# 2     2022-03-23
# 3     2022-03-17
# 4     2022-03-17
#          ...
# 182   2017-11-28
# 183   2017-10-25
# 184   2017-10-19
# 185   2017-09-13
# 186   2017-08-03
# Name: createdAt, Length: 24005, dtype: datetime64[ns]

# %%
comments.dtypes
# Out:
# id                          int64
# name                       object
# anonymous                    bool
# hostProgramName            object
# graduatingYear              int64
# isAlumni                   object
# jobTitle                   object
# tagline                    object
# body                       object
# rawBody                    object
# createdAt          datetime64[ns]
# queryDate          datetime64[ns]
# program                    object
# user                       object
# overallScore              float64
# comments                   object
# overall                   float64
# curriculum                float64
# jobSupport                float64
# review_body                object
# school                     object
# dtype: object

# %%
comments.sample(3)
# Out:
#          id            name  anonymous       hostProgramName  graduatingYear  \
# 168  245267       Anonymous       True          Data Science            2018
# 104  256073  David Ferreira      False  Software Engineering            2019
# 36   286145       Anonymous       True                  None            2022
#
#     isAlumni     jobTitle                                            tagline  \
# 168     True         None                       Great intro do deep learning
# 104     True         None                                   Amazing Bootcamp
# 36      True  UX Designer  Helpful and insightful. Really worked with my ...
#
#                                                   body  \
# 168  <span class="truncatable"><p>I enrolled in thi...
# 104  <p>The bootcamp was an experience that prepare...
# 36   <span class="truncatable"><p></p><p>I learned ...
#
#                                                rawBody  ...  queryDate  \
# 168  I enrolled in this course with some working kn...  ... 2018-10-29
# 104  The <Academia de Código_> bootcamp was an expe...  ... 2019-10-04
# 36   <p>I learned a lot. I plan on transitioning to...  ... 2022-02-22
#
#            program             user overallScore  comments overall  \
# 168  Deep Learning  {'image': None}          4.5        []     4.0
# 104           None  {'image': None}          5.0        []     5.0
# 36      UX Academy  {'image': None}          3.7        []     4.0
#
#      curriculum  jobSupport  \
# 168         5.0         NaN
# 104         5.0         5.0
# 36          4.0         3.0
#
#                                            review_body  \
# 168  I enrolled in this course with some working kn...
# 104  The bootcamp was an experience that prepared m...
# 36   I learned a lot. I plan on transitioning to UX...
#
#                        school
# 168  nyc-data-science-academy
# 104        academia-de-codigo
# 36                  designlab
#
# [3 rows x 21 columns]

# %%
#Not usefull columns
# user
comments['user'].sample(4)
# Out:
# 95      {'image': None}
# 1184    {'image': None}
# 1220    {'image': None}
# 1377    {'image': None}
# Name: user, dtype: object

# %%
#Already droped,
#comments.drop(['user'],axis=1,inplace=True)

# %%
comments.head()
# Out:
#        id                  name  anonymous hostProgramName  graduatingYear  \
# 0  287305  Javier Leyva Seiglie      False            None            2022
# 1  287077         Oswaldo Salas      False            None            2021
# 2  287024         Oswaldo Salas      False            None            2021
# 3  286880       Aaron Arismendi      False            None            2021
# 4  286878          Octavio Lara      False            None            2021
#
#   isAlumni                  jobTitle  \
# 0    False  Full Stack web developer
# 1    False
# 2    False
# 3    False  Desarrollador Full Stack
# 4    False         Software engineer
#
#                                      tagline  \
# 0          On a simple word, the actual best
# 1  Obtener mucho conocimiento sin frustrarte
# 2  Obtener mucho conocimiento sin frustrarte
# 3                      Una experiencia única
# 4                    A fulfilling experience
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>This is a ...
# 1  <span class="truncatable"><p></p><p>Me gusto m...
# 2  <span class="truncatable"><p></p><p>Particular...
# 3  <span class="truncatable"><p></p><p>No sabía n...
# 4  <span class="truncatable"><p></p><p>I'd say th...
#
#                                              rawBody  ...  queryDate  \
# 0  <p>This is a beast! The best! I attain the ful...  ... 2022-04-01
# 1  <p>Me gusto mucho la din&aacute;mica para ir s...  ... 2022-03-24
# 2  <p>Particularmente creo que el programa de ent...  ... 2022-03-23
# 3  <p>No sab&iacute;a nada a cerca de programaci&...  ... 2022-03-17
# 4  <p>I&#39;d say the main pro would be the commu...  ... 2022-03-17
#
#                                      program             user overallScore  \
# 0            Full Stack Software Development  {'image': None}          5.0
# 1            Full Stack Software Development  {'image': None}          5.0
# 2            Full Stack Software Development  {'image': None}          3.7
# 3            Full Stack Software Development  {'image': None}          5.0
# 4  Full Stack Software Development Part Time  {'image': None}          5.0
#
#    comments overall  curriculum  jobSupport  \
# 0        []     5.0         5.0         5.0
# 1        []     5.0         5.0         5.0
# 2        []     5.0         5.0         1.0
# 3        []     5.0         5.0         5.0
# 4        []     5.0         5.0         5.0
#
#                                          review_body          school
# 0  This is a beast! The best! I attain the full s...  4geeks-academy
# 1  Me gusto mucho la dinámica para ir superando c...  4geeks-academy
# 2  Particularmente creo que el programa de entren...  4geeks-academy
# 3  No sabía nada a cerca de programación hasta qu...  4geeks-academy
# 4  I'd say the main pro would be the community. T...  4geeks-academy
#
# [5 rows x 21 columns]

# %%
#Adjust Text eliminaring <p>
comments['rawBody'] = comments['rawBody'].str.replace('<p>','')
comments['rawBody']
#= comments['rawBody']
# Out:
# 0      This is a beast! The best! I attain the full s...
# 1      Me gusto mucho la din&aacute;mica para ir supe...
# 2      Particularmente creo que el programa de entren...
# 3      No sab&iacute;a nada a cerca de programaci&oac...
# 4      I&#39;d say the main pro would be the communit...
#                              ...
# 182    You never know how you can improve if you don'...
# 183    This course has provided me with the right too...
# 184    Nice bootcamp for people to learn who to codin...
# 185    Everything I learned was broad enough to be re...
# 186    Accelerate was a good choice for me because I ...
# Name: rawBody, Length: 24005, dtype: object

# %%
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p></p><p>','')
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p>','')
comments['body'] = comments['body'].str.replace('<p>','')
badges['description'] = badges['description'].str.replace('</p>','')
comments['body'].sample(6)
# Out:
# 214    I actually searched online for different PM co...
# 49     This was a great program to get started and it...
# 230    Are you stuck in a career that you aren't pass...
# 340    I recently graduated and am freshly entering t...
# 12     I thought the class was very informational &am...
# 86     Well, to be honest, I was really scared to sta...
# Name: body, dtype: object

# %%
comments.sample(5)
# Out:
#          id              name  anonymous       hostProgramName  \
# 55   285920         Anonymous       True                  None
# 167  275276             David      False                  None
# 151  267579          Andrew H      False                  None
# 183  268708          Olivia B      False                  None
# 642  244815  Otniel Gutiérrez      False  Software Engineering
#
#      graduatingYear isAlumni                  jobTitle  \
# 55             2022    False
# 167            2020    False     Junior Java Developer
# 151            2020    False
# 183            2020    False   Digital Project Manager
# 642            2018     True  Full Stack Web Developer
#
#                                              tagline  \
# 55                              SheCodes is awesome!
# 167                     It delivers on its promises.
# 151                        Great Learning Experience
# 183  It was definitely a very good decision for me !
# 642                              Increíble pero real
#
#                                                   body  \
# 55   SheCodes Basic was amazing! The curriculum is ...
# 167  I have managed to successfully change my caree...
# 151  Overall, I'm very happy I decided to join Iron...
# 183  I have worked for several years in digital mar...
# 642  Soy un chavo de 23 años que no sabía hacer nad...
#
#                                                rawBody  ...  queryDate  \
# 55   SheCodes Basic was amazing! The curriculum is ...  ... 2022-02-16
# 167  I have managed to successfully change my caree...  ... 2021-03-29
# 151  Overall, I'm very happy I decided to join Iron...  ... 2020-08-18
# 183  I have worked for several years in digital mar...  ... 2020-09-23
# 642  Soy un chavo de 23 años que no sabía hacer nad...  ... 2018-08-22
#
#                                  program             user overallScore  \
# 55                       SheCodes Basics  {'image': None}          5.0
# 167                            Java - EE  {'image': None}          5.0
# 151             Web Development Bootcamp  {'image': None}          5.0
# 183   Fullstack JavaScript Web Developer  {'image': None}          5.0
# 642  Full-time Web Development Bootcamp   {'image': None}          5.0
#
#      comments overall  curriculum  jobSupport  \
# 55         []     5.0         5.0         5.0
# 167        []     5.0         5.0         5.0
# 151        []     5.0         5.0         5.0
# 183        []     5.0         5.0         5.0
# 642        []     5.0         5.0         5.0
#
#                                            review_body  \
# 55   SheCodes Basic was amazing! The curriculum is ...
# 167  I have managed to successfully change my caree...
# 151  Overall, I'm very happy I decided to join Iron...
# 183  I have worked for several years in digital mar...
# 642  Soy un chavo de 23 años que no sabía hacer nad...
#
#                            school
# 55                       shecodes
# 167  software-development-academy
# 151                      ironhack
# 183                    la-capsule
# 642                      ironhack
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Table locations

# %%
locations.sample(5)
# Out:
#        id                    description  country.id   country.name  \
# 2   17720                         Online         NaN            NaN
# 1   16426                Berlin, Germany        57.0        Germany
# 89  16904  Tuscaloosa, AL, United States         1.0  United States
# 11  16592                         Online         NaN            NaN
# 0   16627               Lisbon, Portugal        28.0       Portugal
#
#    country.abbrev  state.id state.name state.abbrev state.keyword  city.id  \
# 2             NaN       1.0     Online       Online        online      NaN
# 1              DE       NaN        NaN          NaN           NaN  31156.0
# 89             US       2.0    Alabama           AL       alabama    697.0
# 11            NaN       1.0     Online       Online        online      NaN
# 0              PT       NaN        NaN          NaN           NaN  31075.0
#
#      city.name city.keyword              school  school_id
# 2          NaN          NaN         product-gym      10959
# 1       Berlin       berlin       careerfoundry      10581
# 89  Tuscaloosa   tuscaloosa              nucamp      10923
# 11         NaN          NaN      product-school      10960
# 0       Lisbon       lisbon  academia-de-codigo      10494

# %%
locations.columns = locations.columns.str.replace('.', '_')
# Out:
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_2332/1538475286.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   locations.columns = locations.columns.str.replace('.', '_')

# %%
locations.sample(5)
# Out:
#        id                  description  country_id   country_name  \
# 13  17137           Strasbourg, France        38.0         France
# 13  16828  Bellevue, WA, United States         1.0  United States
# 1   16127  Columbus, OH, United States         1.0  United States
# 3   16759        Maracaibo , Venezuela        58.0      Venezuela
# 0   15712                  Seattle, WA         1.0  United States
#
#    country_abbrev  state_id  state_name state_abbrev state_keyword  city_id  \
# 13             FR       NaN         NaN          NaN           NaN  31190.0
# 13             US      49.0  Washington           WA    washington   1193.0
# 1              US      37.0        Ohio           OH          ohio     70.0
# 3              VE       NaN         NaN          NaN           NaN  31160.0
# 0              US      49.0  Washington           WA    washington   1193.0
#
#      city_name city_keyword            school  school_id
# 13  Strasbourg   strasbourg  wild-code-school      11169
# 13    Bellevue     bellevue            nucamp      10923
# 1     Columbus     columbus     tech-elevator      11056
# 3   Maracaibo     maracaibo    4geeks-academy      10492
# 0     Bellevue     bellevue       coding-dojo      10659

# %%
locations.dtypes
# Out:
# id                  int64
# description        object
# country_id        float64
# country_name       object
# country_abbrev     object
# state_id          float64
# state_name         object
# state_abbrev       object
# state_keyword      object
# city_id           float64
# city_name          object
# city_keyword       object
# school             object
# school_id           int64
# dtype: object

# %%
#Validation for empty values
locations.isnull().sum()
# Out:
# id                  0
# description         0
# country_id         65
# country_name       65
# country_abbrev     65
# state_id          228
# state_name        228
# state_abbrev      228
# state_keyword     229
# city_id            66
# city_name          66
# city_keyword       66
# school              0
# school_id           0
# dtype: int64

# %%
locations.isna()
# Out:
#        id  description  country_id  country_name  country_abbrev  state_id  \
# 0   False        False       False         False           False     False
# 1   False        False       False         False           False      True
# 2   False        False       False         False           False      True
# 3   False        False       False         False           False      True
# 4   False        False       False         False           False      True
# ..    ...          ...         ...           ...             ...       ...
# 24  False        False        True          True            True     False
# 25  False        False       False         False           False      True
# 0   False        False       False         False           False     False
# 0   False        False       False         False           False      True
# 1   False        False        True          True            True     False
#
#     state_name  state_abbrev  state_keyword  city_id  city_name  city_keyword  \
# 0        False         False          False    False      False         False
# 1         True          True           True    False      False         False
# 2         True          True           True    False      False         False
# 3         True          True           True    False      False         False
# 4         True          True           True    False      False         False
# ..         ...           ...            ...      ...        ...           ...
# 24       False         False          False     True       True          True
# 25        True          True           True    False      False         False
# 0        False         False          False    False      False         False
# 0         True          True           True    False      False         False
# 1        False         False          False     True       True          True
#
#     school  school_id
# 0    False      False
# 1    False      False
# 2    False      False
# 3    False      False
# 4    False      False
# ..     ...        ...
# 24   False      False
# 25   False      False
# 0    False      False
# 0    False      False
# 1    False      False
#
# [506 rows x 14 columns]

# %%
locations[['description','country_id','country_name']].sample(4)
#Empty conuntries is bevause is online
# Out:
#                   description  country_id   country_name
# 0                      Online         NaN            NaN
# 3   Boston, MA, United States         1.0  United States
# 1            Barcelona, Spain        12.0          Spain
# 27           Craiova, Romania         4.0        Romania

# %%
locations['description'][locations['country_name'].isnull()].unique()
# Out:
# array(['Online'], dtype=object)

# %% [markdown]
# ### Table courses

# %%
#This one looks ok
courses
# Out:
#                                               courses              school  \
# 0          Ai and Machine Learning Full-Stack Program      4geeks-academy
# 1                     Full Stack Software Development      4geeks-academy
# 2           Full Stack Software Development Part Time      4geeks-academy
# 0   14-Week Intensive && Immersive Full-Stack Prog...  academia-de-codigo
# 0                Actualize Coding Bootcamp: Full-Time           actualize
# ..                                                ...                 ...
# 5       Data Science and Machine Learning (Part-time)          xccelerate
# 6                                  Python for Finance          xccelerate
# 7                                 Python Fundamentals          xccelerate
# 8   Software Engineering Immersive Bootcamp (Full-...          xccelerate
# 9                                           UX Design          xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 2       10492
# 0       10494
# 0       10505
# ..        ...
# 5       11175
# 6       11175
# 7       11175
# 8       11175
# 9       11175
#
# [536 rows x 3 columns]

# %%
courses.dtypes
# Out:
# courses      object
# school       object
# school_id     int64
# dtype: object

# %% [markdown]
# ### Table badges

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0               <p>School offers fully online courses  4geeks-academy
# 1      <p>School offers part-time and evening classes  4geeks-academy
# 0               <p>School offers fully online courses       actualize
# 1      <p>School offers part-time and evening classes       actualize
# 0               <p>School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   <p>School publishes a third-party verified out...         wyncode
# 2      <p>School offers part-time and evening classes         wyncode
# 3                       <p>School accepts the GI Bill         wyncode
# 0               <p>School offers fully online courses      xccelerate
# 1      <p>School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %%
badges.dtypes
# Out:
# name           object
# keyword        object
# description    object
# school         object
# school_id       int64
# dtype: object

# %%
#For cleaning function
#badges['description'] = badges['description'].apply(clean_text_tag(badges['description']))
#badges['description']

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0               <p>School offers fully online courses  4geeks-academy
# 1      <p>School offers part-time and evening classes  4geeks-academy
# 0               <p>School offers fully online courses       actualize
# 1      <p>School offers part-time and evening classes       actualize
# 0               <p>School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   <p>School publishes a third-party verified out...         wyncode
# 2      <p>School offers part-time and evening classes         wyncode
# 3                       <p>School accepts the GI Bill         wyncode
# 0               <p>School offers fully online courses      xccelerate
# 1      <p>School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %%
#Clean text from tags
badges['description'] = badges['description'].str.replace('<span class="truncatable"><p></p><p>','')
badges['description'] = badges['description'].str.replace('<span class="truncatable"><p>','')
badges['description'] = badges['description'].str.replace('<p>','')
badges['description'] = badges['description'].str.replace('</p>','')
badges['description'].sample(6)
# Out:
# 1    School offers part-time and evening classes
# 0             School offers fully online courses
# 0             School offers fully online courses
# 0             School offers fully online courses
# 1    School offers part-time and evening classes
# 2    School offers part-time and evening classes
# Name: description, dtype: object

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0                  School offers fully online courses  4geeks-academy
# 1         School offers part-time and evening classes  4geeks-academy
# 0                  School offers fully online courses       actualize
# 1         School offers part-time and evening classes       actualize
# 0                  School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   School publishes a third-party verified outcom...         wyncode
# 2         School offers part-time and evening classes         wyncode
# 3                          School accepts the GI Bill         wyncode
# 0                  School offers fully online courses      xccelerate
# 1         School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %% [markdown]
# ### Table schools

# %%
schools
# Out:
#                                               website  \
# 0                                www.4geeksacademy.co
# 0                        applyto.academiadecodigo.org
# 0   anyonecanlearntocode.com/?utm_source=switchup&...
# 0                                   www.altcademy.com
# 0                                       appacademy.io
# ..                                                ...
# 0                              uxdesigninstitute.com/
# 0                                  www.uxerschool.com
# 0                                  wildcodeschool.com
# 0                                      www.wyncode.co
# 0                                       xccelerate.co
#
#                                           description  \
# 0   <span class="truncatable"><p>4Geeks Academy is...
# 0   <span class="truncatable"><p>Founded in Lisbon...
# 0   <span class="truncatable"><p>Actualize is a co...
# 0   <span class="truncatable"><p>Altcademy is a 10...
# 0   <span class="truncatable"><p>App Academy is a ...
# ..                                                ...
# 0   <span class="truncatable"><p>The UX Design Ins...
# 0   <span class="truncatable"><p>UXER School is an...
# 0   <span class="truncatable"><p>Wild Code School ...
# 0   <span class="truncatable"><p>Wyncode Academy i...
# 0   <span class="truncatable"><p>Xccelerate is a s...
#
#                                               LogoUrl               school  \
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...       4geeks-academy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...   academia-de-codigo
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            actualize
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            altcademy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# ..                                                ...                  ...
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...  ux-design-institute
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          uxer-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...     wild-code-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...              wyncode
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...           xccelerate
#
#     school_id
# 0       10492
# 0       10494
# 0       10505
# 0       10517
# 0       10525
# ..        ...
# 0       11150
# 0       11151
# 0       11169
# 0       11174
# 0       11175
#
# [78 rows x 5 columns]

# %%
schools.dtypes
# Out:
# website        object
# description    object
# LogoUrl        object
# school         object
# school_id       int64
# dtype: object

# %%
#Clean text from tags
schools['description'] = schools['description'].str.replace('<span class="truncatable"><p></p><p>','')
schools['description'] = schools['description'].str.replace('<span class="truncatable"><p>','')
schools['description'] = schools['description'].str.replace('<p>','')
schools['description'] = schools['description'].str.replace('</p>','')
schools['description'].sample(6)
# Out:
# 0    Dataquest offers online, 24-week project-based...
# 0    Practicum is an online coding bootcamp aimed a...
# 0    The UX Design Institute offers 6 month, online...
# 0    Ironhack is a global tech school with 9 campus...
# 0    Devmountain is a coding bootcamp and design sc...
# 0    Microverse offers an online, full-time, Full S...
# Name: description, dtype: object

# %%
schools
# Out:
#                                               website  \
# 0                                www.4geeksacademy.co
# 0                        applyto.academiadecodigo.org
# 0   anyonecanlearntocode.com/?utm_source=switchup&...
# 0                                   www.altcademy.com
# 0                                       appacademy.io
# ..                                                ...
# 0                              uxdesigninstitute.com/
# 0                                  www.uxerschool.com
# 0                                  wildcodeschool.com
# 0                                      www.wyncode.co
# 0                                       xccelerate.co
#
#                                           description  \
# 0   4Geeks Academy is a Coding Bootcamp focused on...
# 0   Founded in Lisbon in 2015, this Portuguese-bor...
# 0   Actualize is a coding bootcamp that values qua...
# 0   Altcademy is a 100% online education institute...
# 0   App Academy is a coding school that offers onl...
# ..                                                ...
# 0   The UX Design Institute offers 6 month, online...
# 0   UXER School is an education startup, specializ...
# 0   Wild Code School offers 5-month web developmen...
# 0   Wyncode Academy is a premier technical educato...
# 0   Xccelerate is a socially-aligned education sta...
#
#                                               LogoUrl               school  \
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...       4geeks-academy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...   academia-de-codigo
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            actualize
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            altcademy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# ..                                                ...                  ...
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...  ux-design-institute
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          uxer-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...     wild-code-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...              wyncode
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...           xccelerate
#
#     school_id
# 0       10492
# 0       10494
# 0       10505
# 0       10517
# 0       10525
# ..        ...
# 0       11150
# 0       11151
# 0       11169
# 0       11174
# 0       11175
#
# [78 rows x 5 columns]

# %%
# Reseting all indexes

comments = comments.reset_index()
locations = locations.reset_index()
badges = badges.reset_index()
schools = schools.reset_index()
courses = courses.reset_index()

# %%
# Dropped columns: "user" and "comments" in comments to avoid problems 

comments.drop(['user','comments'], axis='columns', inplace=True)

# %% [markdown]
# ## Sending dataframes to MySQL

# %%
import mysql.connector
import getpass

saved_password = getpass.getpass()
cnx = mysql.connector.connect(user = 'root', # Specify your user 
                              password = saved_password, 
                              host ='localhost', 
                              database = 'sakila',
                              auth_plugin='mysql_native_password')
# Out:
# ········

# %%
cnx.is_connected()
if cnx.is_connected():
    print("Connection open")
    # do stuff you need to the database
else:
    print("Connection is not successfully open")
# Out:
# Connection open

# %%
cursor = cnx.cursor()

#Create database

def sql_db(db_name):
    query = f"CREATE DATABASE {db_name}"
    print(query)
    use_db = f"USE {db_name}"
    print(use_db)
    cursor.execute(query)
    cursor.execute(use_db)
    return db_name 

#Execute the full process of a query

def sql_action():
    query = input('Please write your query...')
    #cursor.execute(query,multi=True)
    results = cursor.fetchall()
    results_df = pd.DataFrame(results)
    return "Action completed" 

#Finalize SQL process

def sql_close_connection():
    return cnx.commit(), cursor.close(), cnx.close()

# %%
# Creating database - create it as string

db = sql_db("sql_project")
# Out:
# CREATE DATABASE sql_project
# USE sql_project

# %%
# Alchemy setup 

from sqlalchemy import create_engine
import pymysql # run pip install pymysql (pip3 for Mac) 

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw=saved_password,
                               db=db))

# %%
# Alchemy insert values - having problems when looped
badges.to_sql('badges', con = engine, if_exists = 'replace', chunksize = 1000)
locations.to_sql('locations', con = engine, if_exists = 'replace', chunksize = 1000)
courses.to_sql('courses', con = engine, if_exists = 'replace', chunksize = 1000)
schools.to_sql('schools', con = engine, if_exists = 'replace', chunksize = 1000)
comments.to_sql('comments', con = engine, if_exists = 'replace', chunksize = 1000)

# %%
# Setting primary KEYs with pandas default indexes - locations table has already an id so we would need to rename based on another keyword or keep it as level_0
cursor.execute("ALTER TABLE comments ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE schools ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE locations ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE courses ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE badges ADD PRIMARY KEY (level_0)")
cursor.fetchall()
