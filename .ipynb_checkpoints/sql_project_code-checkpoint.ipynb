# %%
#Imports

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # Dictionary with top schools

# %%
schools = {   
'4geeks-academy'  : 10492,
'academia-de-codigo'  : 10494,
'actualize'  : 10505,
'altcademy'  : 10517,
'app-academy'  : 10525,
'bloomtech'  : 10854,
'brainstation'  : 10571,
'careerfoundry'  : 10581,
'careerist'  : 11280,
'claim-academy'  : 10589,
'clarusway'  : 11539,
'code-fellows'  : 10614,
'code-institute'  : 10619,
'codesmith'  : 10643,
'codeworks'  : 10650,
'coding-bootcamp-praha'  : 10658,
'coding-dojo'  : 10659,
'coding-temple'  : 10664,
#'correlation-one'  : 11528,
'datacamp'  : 10682,
'dataquest'  : 10683,
'data-science-dojo'  : 10685,
'datascientest'  : 11232,
'designlab'  : 10697,
'devcodecamp'  : 10703,
'developers-institute'  : 10705,
'devmountain'  : 10710,
'digitalcrafts'  : 10719,
'epicodus'  : 10739,
'evolve-security-academy'  : 10743,
'flatiron-school'  : 10748,
'general-assembly'  : 10761,
'greyatom-school-of-data-science'  : 10776,
'h-academy'  : 11518,
'hack-reactor'  : 10788,
'hacktiv8'  : 10791,
'hackwagon-academy'  : 10792,
'heicoders-academy'  : 11287,
'holberton-school'  : 10796,
'hyperiondev'  : 10801,
'ironhack'  : 10828,
'jedha'  : 10837,
'juno-college-of-technology'  : 10787,
'kenzie-academy'  : 10843,
'knowledgehut'  : 10846,
'la-capsule'  : 10853,
'learningfuze'  : 10862,
'le-wagon'  : 10868,
'lighthouse-labs'  : 10869,
'makers-academy'  : 10874,
'microverse'  : 10888,
'neoland'  : 10906,
'nucamp'  : 10923,
'nyc-data-science-academy'  : 10925,
'practicum'  : 11225,
'product-gym'  : 10959,
'product-school'  : 10960,
'react-graphql-academy'  : 10972,
'rmotr'  : 10987,
'rocket-academy'  : 11483,
'school-of-it'  : 11006,
'shecodes'  : 11014,
'simplilearn'  : 11016,
'sit-academy'  : 10965,
'skillcrush'  : 11020,
'software-development-academy'  : 11030,
'springboard'  : 11035,
'startup-institute'  : 11042,
'tech-elevator'  : 11056,
'tech-talent-south'  : 11059,
'the-job-hackers'  : 11085,
'the-tech-academy'  : 11091,
'thinkful'  : 11098,
'udacity'  : 11118,
'ux-design-institute'  : 11150,
'uxer-school'  : 11151,
'wild-code-school'  : 11169,
'wyncode'  : 11174,
'xccelerate'  : 11175,

}

# %% [markdown]
# # Functions

# %%
#Function for Scraping 
def get_comments_school(school):
    #This function extracts all the 
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
#get_comments_school('wyncode') List comprenhension

# %%
"""comments = [get_comments_school(school) for school in schools.keys()]
print('Finished collecting comments.')
comments = pd.concat(comments)"""
# Out:
# "comments = [get_comments_school(school) for school in schools.keys()]\nprint('Finished collecting comments.')\ncomments = pd.concat(comments)"

# %%
#get_comments_school('wyncode')

# %%
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# 4geeks-academy
# academia-de-codigo
# actualize
# altcademy
# app-academy
# bloomtech
# brainstation
# careerfoundry
# careerist
# claim-academy
# clarusway
# code-fellows
# code-institute
# codesmith
# codeworks
# coding-bootcamp-praha
# coding-dojo
# coding-temple
# datacamp
# dataquest
# data-science-dojo
# datascientest
# designlab
# devcodecamp
# developers-institute
# devmountain
# digitalcrafts
# epicodus
# evolve-security-academy
# flatiron-school
# general-assembly
# greyatom-school-of-data-science
# h-academy
# hack-reactor
# hacktiv8
# hackwagon-academy
# heicoders-academy
# holberton-school
# hyperiondev
# ironhack
# jedha
# juno-college-of-technology
# kenzie-academy
# knowledgehut
# la-capsule
# learningfuze
# le-wagon
# lighthouse-labs
# makers-academy
# microverse
# neoland
# nucamp
# nyc-data-science-academy
# practicum
# product-gym
# product-school
# react-graphql-academy
# rmotr
# rocket-academy
# school-of-it
# shecodes
# simplilearn
# sit-academy
# skillcrush
# software-development-academy
# springboard
# startup-institute
# tech-elevator
# tech-talent-south
# the-job-hackers
# the-tech-academy
# thinkful
# udacity
# ux-design-institute
# uxer-school
# wild-code-school
# wyncode
# xccelerate

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

# %%
locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# 4geeks-academy
# /var/folders/qc/598rf5kn0sz5cshnx3dqfdlw0000gn/T/ipykernel_50428/4240401434.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# academia-de-codigo
# actualize
# altcademy
# app-academy
# bloomtech
# brainstation
# careerfoundry
# careerist
# claim-academy
# clarusway
# code-fellows
# code-institute
# codesmith
# codeworks
# coding-bootcamp-praha
# coding-dojo
# coding-temple
# datacamp
# dataquest
# data-science-dojo
# datascientest
# designlab
# devcodecamp
# developers-institute
# devmountain
# digitalcrafts
# epicodus
# evolve-security-academy
# flatiron-school
# general-assembly
# greyatom-school-of-data-science
# h-academy
# hack-reactor
# hacktiv8
# hackwagon-academy
# heicoders-academy
# holberton-school
# hyperiondev
# ironhack
# jedha
# juno-college-of-technology
# kenzie-academy
# knowledgehut
# la-capsule
# learningfuze
# le-wagon
# lighthouse-labs
# makers-academy
# microverse
# neoland
# nucamp
# nyc-data-science-academy
# practicum
# product-gym
# product-school
# react-graphql-academy
# rmotr
# rocket-academy
# school-of-it
# shecodes
# simplilearn
# sit-academy
# skillcrush
# software-development-academy
# springboard
# startup-institute
# tech-elevator
# tech-talent-south
# the-job-hackers
# the-tech-academy
# thinkful
# udacity
# ux-design-institute
# uxer-school
# wild-code-school
# wyncode
# xccelerate

# %%
#Dataframes creation 
locations = pd.concat(locations_list)
courses = pd.concat(courses_list)
badges = pd.concat(badges_list)
schools = pd.concat(schools_list)

# %%
#Function to clean
def clean_text_tag(col):
    col.str.replace('<span class="truncatable"><p></p><p>','')
    col.str.replace('<span class="truncatable"><p>','')
    col.str.replace('<p>','')
    col.str.replace('</p>','')

# %% [markdown]
# # Dataframes exploration

# %%
# Tables / dataframes
    # comments
    # locations
    # courses
    # badges
    # schools

# %%
#Sizes for all
print('Comments',comments.shape)
print('locations',locations.shape)
print('courses',courses.shape)
print('badges',badges.shape)
print('schools',schools.shape)
# Out:
# Comments (24043, 21)
# locations (506, 14)
# courses (536, 3)
# badges (163, 5)
# schools (78, 5)

# %% [markdown]
# ### We start exploring for cleaning process by table/dataframe

# %%
#we start with comments
comments.describe()
# Out:
#                   id  graduatingYear
# count   24043.000000    23808.000000
# mean   257686.896436     2018.822749
# std     16345.880599        1.842247
# min    231508.000000     2010.000000
# 25%    243286.500000     2018.000000
# 50%    257286.000000     2019.000000
# 75%    271454.500000     2020.000000
# max    287568.000000     2022.000000

# %%
comments.sample(15)
# Out:
#          id                   name  anonymous       hostProgramName  \
# 43   278832      Védric EBOA EBOLO      False                  None
# 48   284154               Cristina      False                  None
# 425  257996    Fernando Toshio Yto      False  Software Engineering
# 333  255549  Muhammad Shaheed Sufi      False          Data Science
# 755  242426               Steven W      False  Software Engineering
# 220  281006        Guillermo Govea      False                  None
# 617  257352           Yash Kankane      False  Software Engineering
# 104  247742                 Rachel      False          UX/UI Design
# 628  245265         Karthika Kumar      False  Software Engineering
# 74   238860           Jozef Andros      False       Web Development
# 145  271021     Jedidiah Amaraegbu      False                  None
# 45   252943                 Nina W      False          UX/UI Design
# 508  273539       Gabriela Paredes      False                  None
# 252  236177                  Faten      False                  None
# 244  245942              Anonymous       True  Software Engineering
#
#      graduatingYear isAlumni                    jobTitle  \
# 43           2021.0     True
# 48           2021.0    False
# 425          2019.0     True                        None
# 333          2019.0     True                        None
# 755          2017.0     True                        None
# 220          2021.0    False
# 617          2017.0    False                        None
# 104          2018.0     True  Associate Product Designer
# 628          2018.0     True               Web Developer
# 74           2017.0     True           Backend Developer
# 145          2020.0     True
# 45           2018.0     True                        None
# 508          2021.0    False              Civil Engineer
# 252          2017.0     True                        None
# 244          2017.0     True           Software Engineer
#
#                                                tagline  \
# 43              A great experience at JEDHA Bootcamp !
# 48                                   Trust the process
# 425               Great course content, school support
# 333                             Hackwagon DS102 Review
# 755                         Full Stack Web Development
# 220  Complete Course, Practical Experience, Great s...
# 617  Best learning experience with the world renown...
# 104  Choosing Bloc was the best decision I've ever ...
# 628                            Great part-time program
# 74                   Massive progress in 12 weeks only
# 145                                   Kudos to Udacity
# 45                                          Fantastic!
# 508                                  Amazing workshop!
# 252                            SEO/SEM &amp; Analytics
# 244  Coding Dojo provided the tools that I needed t...
#
#                                                   body  \
# 43   <span class="truncatable"><p></p><p>When I joi...
# 48   <span class="truncatable"><p></p><p>Because I ...
# 425  <span class="truncatable"><p>Still not working...
# 333  <span class="truncatable"><p>It gave me an eve...
# 755  <span class="truncatable"><p>App Academy has b...
# 220  <span class="truncatable"><p></p><p>Pros: The ...
# 617  <span class="truncatable"><p>This was the firs...
# 104  <span class="truncatable"><p></p><p>Choosing B...
# 628  <span class="truncatable"><p>I really like the...
# 74   <span class="truncatable"><p>I have been inter...
# 145  <span class="truncatable"><p>Kudos to Udacity....
# 45   <span class="truncatable"><p>I completed Hacke...
# 508  <span class="truncatable"><p></p><p>At first I...
# 252  <span class="truncatable"><p>Taking the SEO/SE...
# 244  <span class="truncatable"><p>I began my coding...
#
#                                                rawBody  ...   queryDate  \
# 43   <p>When I joined JEDHA, my only fears were tha...  ...  2021-06-28
# 48   <p>Because I wanted to change my career, I dec...  ...  2021-12-14
# 425  Still not working as a developer, but by talki...  ...  2019-10-22
# 333  It gave me an even more in-depth understanding...  ...  2019-09-28
# 755  App Academy has been a great learning experien...  ...  2018-02-20
# 220  <p>Pros: The course covers the fundamentals of...  ...  2021-08-31
# 617  This was the first time I opted for the paid t...  ...  2019-10-12
# 104  <p>Choosing Bloc as my way into the UX/UI desi...  ...  2019-04-01
# 628  I really like the way classes are organized at...  ...  2018-10-16
# 74   I have been interested in coding for a long ti...  ...  2017-10-18
# 145  Kudos to Udacity.\r\nI am enrolled on the Udac...  ...  2020-12-03
# 45   I completed HackerYou's UX course in fall of 2...  ...  2019-07-29
# 508  <p>At first I was affraid because I had no clu...  ...  2021-02-10
# 252  Taking the SEO/SEM course with BrainStation ha...  ...  2017-05-23
# 244  I began my coding bootcamp journey at Coding D...  ...  2018-12-03
#
#                                                program             user  \
# 43                                                None  {'image': None}
# 48                  Web Development Course - Full-Time  {'image': None}
# 425                          Part-time Web Development  {'image': None}
# 333                                               None  {'image': None}
# 755                 Software Engineer Track: In-Person  {'image': None}
# 220                          Data Science Career Track  {'image': None}
# 617                            Front End Web Developer  {'image': None}
# 104                                                     {'image': None}
# 628               Front End Web and Mobile Development  {'image': None}
# 74                          Full Stack Web Development  {'image': None}
# 145                                              React  {'image': None}
# 45         UX Design Fundamentals & Advanced UX Design  {'image': None}
# 508                           SheCodes Online Workshop  {'image': None}
# 252                     Search Engine Marketing Course  {'image': None}
# 244  Onsite Software Development Immersive Bootcamp...  {'image': None}
#
#     overallScore                                           comments overall  \
# 43           5.0                                                 []     5.0
# 48           5.0                                                 []     5.0
# 425          5.0                                                 []     5.0
# 333          5.0                                                 []     5.0
# 755          5.0                                                 []     5.0
# 220          4.7                                                 []     5.0
# 617          4.0                                                 []     4.0
# 104          5.0                                                 []     5.0
# 628          4.3                                                 []     5.0
# 74           5.0  [{'name': 'jan.vecerka@data4you.cz', 'email': ...     5.0
# 145          4.3                                                 []     4.0
# 45           5.0                                                 []     5.0
# 508          5.0                                                 []     5.0
# 252          5.0                                                 []     5.0
# 244          3.7                                                 []     4.0
#
#     curriculum jobSupport                                        review_body  \
# 43         5.0        5.0  When I joined JEDHA, my only fears were that s...
# 48         5.0        5.0  Because I wanted to change my career, I decide...
# 425        5.0        5.0  Still not working as a developer, but by talki...
# 333        5.0        NaN  It gave me an even more in-depth understanding...
# 755        5.0        5.0  App Academy has been a great learning experien...
# 220        5.0        4.0  Pros: The course covers the fundamentals of da...
# 617        5.0        3.0  This was the first time I opted for the paid t...
# 104        5.0        5.0  Choosing Bloc as my way into the UX/UI design ...
# 628        5.0        3.0  I really like the way classes are organized at...
# 74         5.0        5.0  I have been interested in coding for a long ti...
# 145        5.0        4.0  Kudos to Udacity.I am enrolled on the Udacity ...
# 45         5.0        5.0  I completed HackerYou's UX course in fall of 2...
# 508        5.0        5.0  At first I was affraid because I had no clue a...
# 252        5.0        NaN  Taking the SEO/SEM course with BrainStation ha...
# 244        4.0        3.0  I began my coding bootcamp journey at Coding D...
#
#                          school
# 43                        jedha
# 48                     le-wagon
# 425                    ironhack
# 333           hackwagon-academy
# 755                 app-academy
# 220                 springboard
# 617                     udacity
# 104                    thinkful
# 628                      nucamp
# 74        coding-bootcamp-praha
# 145                     udacity
# 45   juno-college-of-technology
# 508                    shecodes
# 252                brainstation
# 244                 coding-dojo
#
# [15 rows x 21 columns]

# %%
# Review types for the columns
#We can see that some columns should be numbers float/int and they arent 
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear     float64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore        object
# comments            object
# overall             object
# curriculum          object
# jobSupport          object
# review_body         object
# school              object
# dtype: object

# %%
#Validation for empty values
comments.isnull().sum()
# Out:
# id                     0
# name                   0
# anonymous              0
# hostProgramName    13445
# graduatingYear       235
# isAlumni              17
# jobTitle            9285
# tagline                3
# body                   0
# rawBody                0
# createdAt              0
# queryDate              0
# program             3668
# user                   0
# overallScore          48
# comments               0
# overall               50
# curriculum           878
# jobSupport          3187
# review_body            0
# school                 0
# dtype: int64

# %%
#There are empty spaces
comments[comments['overallScore'].isnull()].count()
# Out:
# id                 48
# name               48
# anonymous          48
# hostProgramName    11
# graduatingYear     41
# isAlumni           48
# jobTitle            7
# tagline            47
# body               48
# rawBody            48
# createdAt          48
# queryDate          48
# program            24
# user               48
# overallScore        0
# comments           48
# overall             0
# curriculum          0
# jobSupport          0
# review_body        48
# school             48
# dtype: int64

# %%
comments['overallScore'].unique()
# Out:
# array(['5.0', '3.7', '2.0', '4.7', '4.3', '3.0', '4.0', '4.5', '3.5',
#        '3.3', '2.3', '1.7', '1.5', '1.0', '2.7', '1.3', '2.5', None,
#        '4.2', '4.8', '3.2'], dtype=object)

# %%
comments['overall'].unique()
# Out:
# array(['5.0', '2.0', '4.0', '3.0', '1.0', nan, '4.5', '3.5'], dtype=object)

# %%
comments['overallScore'].value_counts()
# Out:
# 5.0    15865
# 4.7     2951
# 4.3     1672
# 4.0     1496
# 3.7      570
# 4.5      265
# 1.0      230
# 3.3      226
# 3.0      222
# 2.0      116
# 2.7       92
# 2.3       80
# 1.7       73
# 1.3       68
# 3.5       34
# 2.5       16
# 1.5       15
# 4.2        2
# 4.8        1
# 3.2        1
# Name: overallScore, dtype: int64

# %%
comments['overall'].value_counts()
# Out:
# 5.0    20262
# 4.0     2799
# 3.0      360
# 1.0      348
# 2.0      218
# 4.5        5
# 3.5        1
# Name: overall, dtype: int64

# %%
comments['comments'].isnull().sum()
# Out:
# 0

# %%
comments['curriculum'].unique()
# Out:
# array(['5.0', '2.0', '4.0', '3.0', nan, '1.0', '2.5'], dtype=object)

# %%
comments['jobSupport'].unique()
# Out:
# array(['5.0', '1.0', '2.0', '3.0', '4.0', nan], dtype=object)

# %% [markdown]
# ## Cleanning proccess for all the tables

# %% [markdown]
# ### Table comments

# %%
comments[['overallScore','overall','curriculum','jobSupport']] = comments[['overallScore','overall','curriculum','jobSupport']].astype('float64')

# %%
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear     float64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore       float64
# comments            object
# overall            float64
# curriculum         float64
# jobSupport         float64
# review_body         object
# school              object
# dtype: object

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022., 2021., 2020., 2019., 2018., 2016., 2017., 2015., 2014.,
#        2012.,   nan, 2011., 2013., 2010.])

# %%
#For empty/nan we will replace it with 0 , it Could be another Value like No Date
comments['graduatingYear'] = comments['graduatingYear'].fillna(0)

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022., 2021., 2020., 2019., 2018., 2016., 2017., 2015., 2014.,
#        2012.,    0., 2011., 2013., 2010.])

# %%
#pd.to_datetime(comments['graduatingYear'])
#comments['graduatingYear'].dt.strftime('%d.%m.%Y')

comments['graduatingYear'] = comments['graduatingYear'].astype('int64')

# %%
comments['graduatingYear'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2016, 2017, 2015, 2014, 2012,    0,
#        2011, 2013, 2010])

# %%
comments.dtypes
# Out:
# id                   int64
# name                object
# anonymous             bool
# hostProgramName     object
# graduatingYear       int64
# isAlumni            object
# jobTitle            object
# tagline             object
# body                object
# rawBody             object
# createdAt           object
# queryDate           object
# program             object
# user                object
# overallScore       float64
# comments            object
# overall            float64
# curriculum         float64
# jobSupport         float64
# review_body         object
# school              object
# dtype: object

# %%
#Changing column to datetime type
comments['queryDate'] = pd.to_datetime(comments['queryDate'])
#comments['queryDate'].dt.strftime('%d.%m.%Y')
comments['queryDate']
# Out:
# 0     2022-04-01
# 1     2022-03-24
# 2     2022-03-23
# 3     2022-03-17
# 4     2022-03-17
#          ...
# 182   2017-11-28
# 183   2017-10-25
# 184   2017-10-19
# 185   2017-09-13
# 186   2017-08-03
# Name: queryDate, Length: 24043, dtype: datetime64[ns]

# %%
#Changing column to datetime type
comments['createdAt'] = pd.to_datetime(comments['createdAt'])
#comments['queryDate'].dt.strftime('%d.%m.%Y')
comments['createdAt']
# Out:
# 0     2022-04-01
# 1     2022-03-24
# 2     2022-03-23
# 3     2022-03-17
# 4     2022-03-17
#          ...
# 182   2017-11-28
# 183   2017-10-25
# 184   2017-10-19
# 185   2017-09-13
# 186   2017-08-03
# Name: createdAt, Length: 24043, dtype: datetime64[ns]

# %%
comments.dtypes
# Out:
# id                          int64
# name                       object
# anonymous                    bool
# hostProgramName            object
# graduatingYear              int64
# isAlumni                   object
# jobTitle                   object
# tagline                    object
# body                       object
# rawBody                    object
# createdAt          datetime64[ns]
# queryDate          datetime64[ns]
# program                    object
# user                       object
# overallScore              float64
# comments                   object
# overall                   float64
# curriculum                float64
# jobSupport                float64
# review_body                object
# school                     object
# dtype: object

# %%
comments.sample(3)
# Out:
#           id                name  anonymous hostProgramName  graduatingYear  \
# 213   264142           Anonymous       True    UX/UI Design            2019
# 1742  235151          Alex Ramos      False            None            2018
# 809   257049  José Osvaldo Fraga      False            None            2018
#
#      isAlumni                                           jobTitle  \
# 213     False
# 1742     True  Full Stack Developer | Ruby on Rails | Object ...
# 809      True                                               None
#
#                                                 tagline  \
# 213   Skip the UI UX course if you have a better alt...
# 1742                         Thanks Le Wagon Barcelona!
# 809   It was an amazing experience, something that y...
#
#                                                    body  \
# 213   <span class="truncatable"><p>I attended the bo...
# 1742  <span class="truncatable"><p>I was working as ...
# 809   <span class="truncatable"><p></p><p>Study at u...
#
#                                                 rawBody  ...  queryDate  \
# 213   I attended the bootcamp in Barcelona. Even goi...  ... 2020-05-02
# 1742  I was working as a copywriter as well as teach...  ... 2018-04-23
# 809   <p>Study at udacity was very good especially t...  ... 2019-10-11
#
#                     program             user overallScore  comments overall  \
# 213   UX/UI Design Bootcamp  {'image': None}          1.7        []     2.0
# 1742                   None  {'image': None}          5.0        []     5.0
# 809                          {'image': None}          5.0        []     5.0
#
#       curriculum  jobSupport  \
# 213          2.0         1.0
# 1742         5.0         5.0
# 809          5.0         5.0
#
#                                             review_body    school
# 213   I attended the bootcamp in Barcelona. Even goi...  ironhack
# 1742  I was working as a copywriter as well as teach...  le-wagon
# 809   Study at udacity was very good especially the ...   udacity
#
# [3 rows x 21 columns]

# %%
#Not usefull columns
# user
comments['user'].sample(4)
# Out:
# 1345    {'image': None}
# 483     {'image': None}
# 14      {'image': None}
# 122     {'image': None}
# Name: user, dtype: object

# %%
#Already droped,
#comments.drop(['user'],axis=1,inplace=True)

# %%
comments.head()
# Out:
#        id                  name  anonymous hostProgramName  graduatingYear  \
# 0  287305  Javier Leyva Seiglie      False            None            2022
# 1  287077         Oswaldo Salas      False            None            2021
# 2  287024         Oswaldo Salas      False            None            2021
# 3  286880       Aaron Arismendi      False            None            2021
# 4  286878          Octavio Lara      False            None            2021
#
#   isAlumni                  jobTitle  \
# 0    False  Full Stack web developer
# 1    False
# 2    False
# 3    False  Desarrollador Full Stack
# 4    False         Software engineer
#
#                                      tagline  \
# 0          On a simple word, the actual best
# 1  Obtener mucho conocimiento sin frustrarte
# 2  Obtener mucho conocimiento sin frustrarte
# 3                      Una experiencia única
# 4                    A fulfilling experience
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>This is a ...
# 1  <span class="truncatable"><p></p><p>Me gusto m...
# 2  <span class="truncatable"><p></p><p>Particular...
# 3  <span class="truncatable"><p></p><p>No sabía n...
# 4  <span class="truncatable"><p></p><p>I'd say th...
#
#                                              rawBody  ...  queryDate  \
# 0  <p>This is a beast! The best! I attain the ful...  ... 2022-04-01
# 1  <p>Me gusto mucho la din&aacute;mica para ir s...  ... 2022-03-24
# 2  <p>Particularmente creo que el programa de ent...  ... 2022-03-23
# 3  <p>No sab&iacute;a nada a cerca de programaci&...  ... 2022-03-17
# 4  <p>I&#39;d say the main pro would be the commu...  ... 2022-03-17
#
#                                      program             user overallScore  \
# 0            Full Stack Software Development  {'image': None}          5.0
# 1            Full Stack Software Development  {'image': None}          5.0
# 2            Full Stack Software Development  {'image': None}          3.7
# 3            Full Stack Software Development  {'image': None}          5.0
# 4  Full Stack Software Development Part Time  {'image': None}          5.0
#
#    comments overall  curriculum  jobSupport  \
# 0        []     5.0         5.0         5.0
# 1        []     5.0         5.0         5.0
# 2        []     5.0         5.0         1.0
# 3        []     5.0         5.0         5.0
# 4        []     5.0         5.0         5.0
#
#                                          review_body          school
# 0  This is a beast! The best! I attain the full s...  4geeks-academy
# 1  Me gusto mucho la dinámica para ir superando c...  4geeks-academy
# 2  Particularmente creo que el programa de entren...  4geeks-academy
# 3  No sabía nada a cerca de programación hasta qu...  4geeks-academy
# 4  I'd say the main pro would be the community. T...  4geeks-academy
#
# [5 rows x 21 columns]

# %%
#Adjust Text eliminaring <p>
comments['rawBody'] = comments['rawBody'].str.replace('<p>','')
comments['rawBody']
#= comments['rawBody']
# Out:
# 0      This is a beast! The best! I attain the full s...
# 1      Me gusto mucho la din&aacute;mica para ir supe...
# 2      Particularmente creo que el programa de entren...
# 3      No sab&iacute;a nada a cerca de programaci&oac...
# 4      I&#39;d say the main pro would be the communit...
#                              ...
# 182    You never know how you can improve if you don'...
# 183    This course has provided me with the right too...
# 184    Nice bootcamp for people to learn who to codin...
# 185    Everything I learned was broad enough to be re...
# 186    Accelerate was a good choice for me because I ...
# Name: rawBody, Length: 24043, dtype: object

# %%
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p></p><p>','')
comments['body'] = comments['body'].str.replace('<span class="truncatable"><p>','')
comments['body'] = comments['body'].str.replace('<p>','')
badges['description'] = badges['description'].str.replace('</p>','')
comments['body'].sample(6)
# Out:
# 302    If I have to describe my experience with Actua...
# 351    I really thought Nucamp would be a great exper...
# 103    This prep course is really good, i have really...
# 21     I cannot recommend this program highly enough....
# 157    Que vous rêviez de devenir développeur, produc...
# 130    I was stuck in an unsatisfying job, underpaid ...
# Name: body, dtype: object

# %%
comments.sample(5)
# Out:
#          id           name  anonymous       hostProgramName  graduatingYear  \
# 135  267152  Amritpal Maan      False  Software Engineering            2019
# 262  245245   Bhavya Doshi      False          Data Science            2018
# 82   236816          Atena      False          UX/UI Design            2017
# 72   245186    Anna Ionova      False  Software Engineering            2018
# 214  264528      Anonymous       True          Data Science            2020
#
#     isAlumni            jobTitle  \
# 135    False
# 262     True  Software developer
# 82      True                None
# 72      True                None
# 214     True
#
#                                                tagline  \
# 135           From a Bartender to a Software Developer
# 262                            Best curriculum offered
# 82         I would not recommend this coding bootcamp.
# 72   I highly recommend HackerYou Part Time Web Dev...
# 214  It was an eye opening course, gain a higher un...
#
#                                                   body  \
# 135  The title sums it up quite well to be honest! ...
# 262  I have came across various programs online but...
# 82   I am slightly editing my review from other pla...
# 72   I was contemplating changing careers, but I wa...
# 214  It was an eye opening course, gain a higher un...
#
#                                                rawBody  ...  queryDate  \
# 135  The title sums it up quite well to be honest! ...  ... 2020-08-03
# 262  I have came across various programs online but...  ... 2019-02-08
# 82   I am slightly editing my review from other pla...  ... 2017-07-13
# 72   I was contemplating changing careers, but I wa...  ... 2018-10-09
# 214  It was an eye opening course, gain a higher un...  ... 2020-05-12
#
#                                                program             user  \
# 135                           Web Development Bootcamp  {'image': None}
# 262        Immersive Data Science Engineering Bootcamp  {'image': None}
# 82                          Full Stack Web Development  {'image': None}
# 72   Web Development Fundamentals & Advanced Web De...  {'image': None}
# 214                                       Data Science  {'image': None}
#
#     overallScore                                           comments overall  \
# 135          5.0                                                 []     5.0
# 262          5.0                                                 []     5.0
# 82           1.7  [{'name': 'jan.vecerka@data4you.cz', 'email': ...     2.0
# 72           5.0                                                 []     5.0
# 214          5.0                                                 []     5.0
#
#      curriculum  jobSupport  \
# 135         5.0         5.0
# 262         5.0         5.0
# 82          2.0         1.0
# 72          5.0         NaN
# 214         5.0         5.0
#
#                                            review_body  \
# 135  The title sums it up quite well to be honest! ...
# 262  I have came across various programs online but...
# 82   I am slightly editing my review from other pla...
# 72   I was contemplating changing careers, but I wa...
# 214  It was an eye opening course, gain a higher un...
#
#                               school
# 135                   makers-academy
# 262  greyatom-school-of-data-science
# 82             coding-bootcamp-praha
# 72        juno-college-of-technology
# 214                hackwagon-academy
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Table locations

# %%
locations.columns = locations.columns.str.replace('.', '_')
# Out:
# /var/folders/qc/598rf5kn0sz5cshnx3dqfdlw0000gn/T/ipykernel_50428/1538475286.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   locations.columns = locations.columns.str.replace('.', '_')

# %%
locations.sample(5)
# Out:
#        id                    description  country_id   country_name  \
# 21  17215                    Detroit, MI         1.0  United States
# 0   16914                         Online         NaN            NaN
# 38  17476                Santiago, Chile        22.0          Chile
# 5   16733  Bellingham, WA, United States         1.0  United States
# 9   17233                         Online         NaN            NaN
#
#    country_abbrev  state_id  state_name state_abbrev state_keyword  city_id  \
# 21             US      24.0    Michigan           MI      michigan     49.0
# 0             NaN       1.0      Online       Online        online      NaN
# 38             CL       NaN         NaN          NaN           NaN  31067.0
# 5              US      49.0  Washington           WA    washington   1183.0
# 9             NaN       1.0      Online       Online        online      NaN
#
#      city_name city_keyword            school  school_id
# 21     Detroit      detroit  general-assembly      10761
# 0          NaN          NaN          shecodes      11014
# 38    Santiago     santiago          le-wagon      10868
# 5   Bellingham   bellingham            nucamp      10923
# 9          NaN          NaN          ironhack      10828

# %%
locations.dtypes
# Out:
# id                  int64
# description        object
# country_id        float64
# country_name       object
# country_abbrev     object
# state_id          float64
# state_name         object
# state_abbrev       object
# state_keyword      object
# city_id           float64
# city_name          object
# city_keyword       object
# school             object
# school_id           int64
# dtype: object

# %%
#Validation for empty values
locations.isnull().sum()
# Out:
# id                  0
# description         0
# country_id         65
# country_name       65
# country_abbrev     65
# state_id          228
# state_name        228
# state_abbrev      228
# state_keyword     229
# city_id            66
# city_name          66
# city_keyword       66
# school              0
# school_id           0
# dtype: int64

# %%
locations.isna()
# Out:
#        id  description  country_id  country_name  country_abbrev  state_id  \
# 0   False        False       False         False           False     False
# 1   False        False       False         False           False      True
# 2   False        False       False         False           False      True
# 3   False        False       False         False           False      True
# 4   False        False       False         False           False      True
# ..    ...          ...         ...           ...             ...       ...
# 24  False        False        True          True            True     False
# 25  False        False       False         False           False      True
# 0   False        False       False         False           False     False
# 0   False        False       False         False           False      True
# 1   False        False        True          True            True     False
#
#     state_name  state_abbrev  state_keyword  city_id  city_name  city_keyword  \
# 0        False         False          False    False      False         False
# 1         True          True           True    False      False         False
# 2         True          True           True    False      False         False
# 3         True          True           True    False      False         False
# 4         True          True           True    False      False         False
# ..         ...           ...            ...      ...        ...           ...
# 24       False         False          False     True       True          True
# 25        True          True           True    False      False         False
# 0        False         False          False    False      False         False
# 0         True          True           True    False      False         False
# 1        False         False          False     True       True          True
#
#     school  school_id
# 0    False      False
# 1    False      False
# 2    False      False
# 3    False      False
# 4    False      False
# ..     ...        ...
# 24   False      False
# 25   False      False
# 0    False      False
# 0    False      False
# 1    False      False
#
# [506 rows x 14 columns]

# %%
locations[['description','country_id','country_name']].sample(4)
#Empty conuntries is bevause is online
# Out:
#          description  country_id country_name
# 12  Lisbon, Portugal        28.0     Portugal
# 0             Online         NaN          NaN
# 44            Online         NaN          NaN
# 0    Berlin, Germany        57.0      Germany

# %%
locations['description'][locations['country_name'].isnull()].unique()
# Out:
# array(['Online'], dtype=object)

# %% [markdown]
# ### Table courses

# %%
#This one looks ok
courses
# Out:
#                                               courses              school  \
# 0          Ai and Machine Learning Full-Stack Program      4geeks-academy
# 1                     Full Stack Software Development      4geeks-academy
# 2           Full Stack Software Development Part Time      4geeks-academy
# 0   14-Week Intensive && Immersive Full-Stack Prog...  academia-de-codigo
# 0                Actualize Coding Bootcamp: Full-Time           actualize
# ..                                                ...                 ...
# 5       Data Science and Machine Learning (Part-time)          xccelerate
# 6                                  Python for Finance          xccelerate
# 7                                 Python Fundamentals          xccelerate
# 8   Software Engineering Immersive Bootcamp (Full-...          xccelerate
# 9                                           UX Design          xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 2       10492
# 0       10494
# 0       10505
# ..        ...
# 5       11175
# 6       11175
# 7       11175
# 8       11175
# 9       11175
#
# [536 rows x 3 columns]

# %%
courses.dtypes
# Out:
# courses      object
# school       object
# school_id     int64
# dtype: object

# %% [markdown]
# ### Table badges

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0               <p>School offers fully online courses  4geeks-academy
# 1      <p>School offers part-time and evening classes  4geeks-academy
# 0               <p>School offers fully online courses       actualize
# 1      <p>School offers part-time and evening classes       actualize
# 0               <p>School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   <p>School publishes a third-party verified out...         wyncode
# 2      <p>School offers part-time and evening classes         wyncode
# 3                       <p>School accepts the GI Bill         wyncode
# 0               <p>School offers fully online courses      xccelerate
# 1      <p>School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %%
badges.dtypes
# Out:
# name           object
# keyword        object
# description    object
# school         object
# school_id       int64
# dtype: object

# %%
#For cleaning function
#badges['description'] = badges['description'].apply(clean_text_tag(badges['description']))
#badges['description']

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0               <p>School offers fully online courses  4geeks-academy
# 1      <p>School offers part-time and evening classes  4geeks-academy
# 0               <p>School offers fully online courses       actualize
# 1      <p>School offers part-time and evening classes       actualize
# 0               <p>School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   <p>School publishes a third-party verified out...         wyncode
# 2      <p>School offers part-time and evening classes         wyncode
# 3                       <p>School accepts the GI Bill         wyncode
# 0               <p>School offers fully online courses      xccelerate
# 1      <p>School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %%
#Clean text from tags
badges['description'] = badges['description'].str.replace('<span class="truncatable"><p></p><p>','')
badges['description'] = badges['description'].str.replace('<span class="truncatable"><p>','')
badges['description'] = badges['description'].str.replace('<p>','')
badges['description'] = badges['description'].str.replace('</p>','')
badges['description'].sample(6)
# Out:
# 3                           School accepts the GI Bill
# 0                   School offers fully online courses
# 1          School offers part-time and evening classes
# 1    School publishes a third-party verified outcom...
# 1          School offers part-time and evening classes
# 1          School offers part-time and evening classes
# Name: description, dtype: object

# %%
badges
# Out:
#                  name            keyword  \
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
# 0    Available Online   available_online
# ..                ...                ...
# 1   Verified Outcomes  verified_outcomes
# 2    Flexible Classes   flexible_classes
# 3     Accepts GI Bill    accepts_gi_bill
# 0    Available Online   available_online
# 1    Flexible Classes   flexible_classes
#
#                                           description          school  \
# 0                  School offers fully online courses  4geeks-academy
# 1         School offers part-time and evening classes  4geeks-academy
# 0                  School offers fully online courses       actualize
# 1         School offers part-time and evening classes       actualize
# 0                  School offers fully online courses       altcademy
# ..                                                ...             ...
# 1   School publishes a third-party verified outcom...         wyncode
# 2         School offers part-time and evening classes         wyncode
# 3                          School accepts the GI Bill         wyncode
# 0                  School offers fully online courses      xccelerate
# 1         School offers part-time and evening classes      xccelerate
#
#     school_id
# 0       10492
# 1       10492
# 0       10505
# 1       10505
# 0       10517
# ..        ...
# 1       11174
# 2       11174
# 3       11174
# 0       11175
# 1       11175
#
# [163 rows x 5 columns]

# %% [markdown]
# ### Table schools

# %%
schools
# Out:
#                                               website  \
# 0                                www.4geeksacademy.co
# 0                        applyto.academiadecodigo.org
# 0   anyonecanlearntocode.com/?utm_source=switchup&...
# 0                                   www.altcademy.com
# 0                                       appacademy.io
# ..                                                ...
# 0                              uxdesigninstitute.com/
# 0                                  www.uxerschool.com
# 0                                  wildcodeschool.com
# 0                                      www.wyncode.co
# 0                                       xccelerate.co
#
#                                           description  \
# 0   <span class="truncatable"><p>4Geeks Academy is...
# 0   <span class="truncatable"><p>Founded in Lisbon...
# 0   <span class="truncatable"><p>Actualize is a co...
# 0   <span class="truncatable"><p>Altcademy is a 10...
# 0   <span class="truncatable"><p>App Academy is a ...
# ..                                                ...
# 0   <span class="truncatable"><p>The UX Design Ins...
# 0   <span class="truncatable"><p>UXER School is an...
# 0   <span class="truncatable"><p>Wild Code School ...
# 0   <span class="truncatable"><p>Wyncode Academy i...
# 0   <span class="truncatable"><p>Xccelerate is a s...
#
#                                               LogoUrl               school  \
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...       4geeks-academy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...   academia-de-codigo
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            actualize
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            altcademy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# ..                                                ...                  ...
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...  ux-design-institute
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          uxer-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...     wild-code-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...              wyncode
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...           xccelerate
#
#     school_id
# 0       10492
# 0       10494
# 0       10505
# 0       10517
# 0       10525
# ..        ...
# 0       11150
# 0       11151
# 0       11169
# 0       11174
# 0       11175
#
# [78 rows x 5 columns]

# %%
schools.dtypes
# Out:
# website        object
# description    object
# LogoUrl        object
# school         object
# school_id       int64
# dtype: object

# %%
#Clean text from tags
schools['description'] = schools['description'].str.replace('<span class="truncatable"><p></p><p>','')
schools['description'] = schools['description'].str.replace('<span class="truncatable"><p>','')
schools['description'] = schools['description'].str.replace('<p>','')
schools['description'] = schools['description'].str.replace('</p>','')
schools['description'].sample(6)
# Out:
# 0    Founded in Lisbon in 2015, this Portuguese-bor...
# 0    Developers.Institute is a selective &amp; inte...
# 0    Simplilearn is the world's #1 online Bootcamp ...
# 0    Lighthouse Labs will take you from coding hobb...
# 0    Codeworks is an immersive coding bootcamp with...
# 0    Tech Elevator offers a full-stack coding bootc...
# Name: description, dtype: object

# %%
schools
# Out:
#                                               website  \
# 0                                www.4geeksacademy.co
# 0                        applyto.academiadecodigo.org
# 0   anyonecanlearntocode.com/?utm_source=switchup&...
# 0                                   www.altcademy.com
# 0                                       appacademy.io
# ..                                                ...
# 0                              uxdesigninstitute.com/
# 0                                  www.uxerschool.com
# 0                                  wildcodeschool.com
# 0                                      www.wyncode.co
# 0                                       xccelerate.co
#
#                                           description  \
# 0   4Geeks Academy is a Coding Bootcamp focused on...
# 0   Founded in Lisbon in 2015, this Portuguese-bor...
# 0   Actualize is a coding bootcamp that values qua...
# 0   Altcademy is a 100% online education institute...
# 0   App Academy is a coding school that offers onl...
# ..                                                ...
# 0   The UX Design Institute offers 6 month, online...
# 0   UXER School is an education startup, specializ...
# 0   Wild Code School offers 5-month web developmen...
# 0   Wyncode Academy is a premier technical educato...
# 0   Xccelerate is a socially-aligned education sta...
#
#                                               LogoUrl               school  \
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...       4geeks-academy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...   academia-de-codigo
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            actualize
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...            altcademy
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# ..                                                ...                  ...
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...  ux-design-institute
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...          uxer-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...     wild-code-school
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...              wyncode
# 0   https://d92mrp7hetgfk.cloudfront.net/images/si...           xccelerate
#
#     school_id
# 0       10492
# 0       10494
# 0       10505
# 0       10517
# 0       10525
# ..        ...
# 0       11150
# 0       11151
# 0       11169
# 0       11174
# 0       11175
#
# [78 rows x 5 columns]

# %%
# Dropped columns: "user" and "comments" in comments to avoid problems 

comments.drop(['user','comments'], axis='columns', inplace=True)

# %% [markdown]
# ### Table ICT_sector_in_GDP

# %%
itc_gdp = pd.read_csv('./data/ICT_sector_in_GDP.csv')

# %%
itc_gdp
# Out:
#       TIME              GEO                                           NACE_R2  \
# 0     2010            Malta  Information and Communication Technology - Total
# 1     2010            Malta                                 ICT manufacturing
# 2     2010            Malta                                      ICT services
# 3     2010       Luxembourg  Information and Communication Technology - Total
# 4     2010       Luxembourg                                 ICT manufacturing
# ...    ...              ...                                               ...
# 1105  2019  North Macedonia                                 ICT manufacturing
# 1106  2019  North Macedonia                                      ICT services
# 1107  2019           Turkey  Information and Communication Technology - Total
# 1108  2019           Turkey                                 ICT manufacturing
# 1109  2019           Turkey                                      ICT services
#
#      Value Flag and Footnotes
# 0     7.23                NaN
# 1        :                  c
# 2        :                  c
# 3        :                  c
# 4        :                  c
# ...    ...                ...
# 1105     :                  c
# 1106     :                  c
# 1107     :                NaN
# 1108     :                NaN
# 1109     :                NaN
#
# [1110 rows x 5 columns]

# %%
itc_gdp.rename(columns={'Value':'contributionsector'},inplace =True)
itc_gdp
# Out:
#       TIME              GEO                                           NACE_R2  \
# 0     2010            Malta  Information and Communication Technology - Total
# 1     2010            Malta                                 ICT manufacturing
# 2     2010            Malta                                      ICT services
# 3     2010       Luxembourg  Information and Communication Technology - Total
# 4     2010       Luxembourg                                 ICT manufacturing
# ...    ...              ...                                               ...
# 1105  2019  North Macedonia                                 ICT manufacturing
# 1106  2019  North Macedonia                                      ICT services
# 1107  2019           Turkey  Information and Communication Technology - Total
# 1108  2019           Turkey                                 ICT manufacturing
# 1109  2019           Turkey                                      ICT services
#
#      contributionsector Flag and Footnotes
# 0                  7.23                NaN
# 1                     :                  c
# 2                     :                  c
# 3                     :                  c
# 4                     :                  c
# ...                 ...                ...
# 1105                  :                  c
# 1106                  :                  c
# 1107                  :                NaN
# 1108                  :                NaN
# 1109                  :                NaN
#
# [1110 rows x 5 columns]

# %%
# Filtering GDP 2019 and only ICT Services 
itc_services = itc_gdp[['TIME','GEO','contributionsector']][(itc_gdp['TIME'] == 2019) & (itc_gdp['NACE_R2'] == 'ICT services')]
itc_services.loc[itc_services['contributionsector'] == ':'] = 0
itc_services
# Out:
#       TIME                                               GEO  \
# 1001  2019                                             Malta
# 1004  2019                                        Luxembourg
# 1007  2019                                            Cyprus
# 1010  2019                                          Bulgaria
# 1013  2019                                            Sweden
# 1016  2019                                           Estonia
# 1019  2019                                            Latvia
# 1022  2019                                       Netherlands
# 1025  2019                                            Serbia
# 1028  2019                                           Finland
# 1031  2019                                           Czechia
# 1034  2019                                           Croatia
# 1037  2019                            Bosnia and Herzegovina
# 1040  2019                                           Hungary
# 1043  2019                                           Denmark
# 1046  2019                                           Iceland
# 1049  2019         European Union - 27 countries (from 2020)
# 1052  2019                                           Belgium
# 1055  2019  Germany (until 1990 former territory of the FRG)
# 1058  2019                                          Slovakia
# 1061  2019                                            France
# 1064  2019                                            Norway
# 1067  2019                                           Romania
# 1070  2019                                          Portugal
# 1073  2019                                          Slovenia
# 1076  2019                                             Spain
# 1079  2019                                         Lithuania
# 1082  2019                                            Poland
# 1085  2019                                           Austria
# 1088  2019                                             Italy
# 1091  2019                                            Greece
# 1094     0                                                 0
# 1097     0                                                 0
# 1100     0                                                 0
# 1103     0                                                 0
# 1106     0                                                 0
# 1109     0                                                 0
#
#      contributionsector
# 1001               7.11
# 1004               6.88
# 1007               6.82
# 1010               6.42
# 1013               6.31
# 1016               5.25
# 1019                  5
# 1022               4.69
# 1025               4.67
# 1028               4.66
# 1031               4.38
# 1034               4.38
# 1037               4.38
# 1040               4.35
# 1043               4.31
# 1046               4.16
# 1049               4.05
# 1052               3.99
# 1055               3.97
# 1058               3.96
# 1061               3.93
# 1064               3.67
# 1067               3.44
# 1070               3.41
# 1073               3.39
# 1076               3.34
# 1079               3.34
# 1082               3.33
# 1085               3.15
# 1088                3.1
# 1091               2.24
# 1094                  0
# 1097                  0
# 1100                  0
# 1103                  0
# 1106                  0
# 1109                  0

# %%
#Top 13 itc_services for sql
itc_services_top12 = itc_services.iloc[:12]
itc_services_top12
# Out:
#       TIME          GEO contributionsector
# 1001  2019        Malta               7.11
# 1004  2019   Luxembourg               6.88
# 1007  2019       Cyprus               6.82
# 1010  2019     Bulgaria               6.42
# 1013  2019       Sweden               6.31
# 1016  2019      Estonia               5.25
# 1019  2019       Latvia                  5
# 1022  2019  Netherlands               4.69
# 1025  2019       Serbia               4.67
# 1028  2019      Finland               4.66
# 1031  2019      Czechia               4.38
# 1034  2019      Croatia               4.38

# %%
"""itc_services_top12['Value'] = itc_services_top12['Value'].astype(float)
itc_services_top12['GEO'] = itc_services_top12['GEO'].astype(str)"""
# Out:
# "itc_services_top12['Value'] = itc_services_top12['Value'].astype(float)\nitc_services_top12['GEO'] = itc_services_top12['GEO'].astype(str)"

# %%
itc_services_top12.dtypes
# Out:
# TIME                   int64
# GEO                   object
# contributionsector    object
# dtype: object

# %%
"""# the itc_services[“Value”] has “:” stored as value and it needs to be changed to an integer in order
# to be able to sort the values
itc_services.loc[itc_services['Value'] == ':'] = 0
itc_services                                         #.................TABLE FOR SQL"""
# Out:
# "# the itc_services[“Value”] has “:” stored as value and it needs to be changed to an integer in order\n# to be able to sort the values\nitc_services.loc[itc_services['Value'] == ':'] = 0\nitc_services                                         #.................TABLE FOR SQL"

# %%
itc_services_top13 = itc_services.iloc[:12]
itc_services_top13
# Out:
#       TIME          GEO contributionsector
# 1001  2019        Malta               7.11
# 1004  2019   Luxembourg               6.88
# 1007  2019       Cyprus               6.82
# 1010  2019     Bulgaria               6.42
# 1013  2019       Sweden               6.31
# 1016  2019      Estonia               5.25
# 1019  2019       Latvia                  5
# 1022  2019  Netherlands               4.69
# 1025  2019       Serbia               4.67
# 1028  2019      Finland               4.66
# 1031  2019      Czechia               4.38
# 1034  2019      Croatia               4.38

# %%
itc_services.dtypes
# Out:
# TIME                   int64
# GEO                   object
# contributionsector    object
# dtype: object

# %%
"""plt.figure(figsize=(18,7))
plt.bar(itc_services_top13['GEO'], itc_services_top13['Value'])
plt.title('GDP by Country', fontsize=20)
plt.ylabel('ICT Services/GDP', fontsize=20)
plt.xticks(rotation=90)
#plt.ylabel('t', fontsize=20)
plt.show()"""
# Out:
# "plt.figure(figsize=(18,7))\nplt.bar(itc_services_top13['GEO'], itc_services_top13['Value'])\nplt.title('GDP by Country', fontsize=20)\nplt.ylabel('ICT Services/GDP', fontsize=20)\nplt.xticks(rotation=90)\n#plt.ylabel('t', fontsize=20)\nplt.show()"

# %% [markdown]
# ### GDP

# %%
gdp_table= pd.read_csv('./data/gdp_capita.csv')

# %%
gdp_table
# Out:
#                  DATAFLOW        LAST UPDATE freq           unit na_item geo  \
# 0    ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  AL
# 1    ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  AL
# 2    ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  AL
# 3    ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  AL
# 4    ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  AL
# ..                    ...                ...  ...            ...     ...  ..
# 837  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  UK
# 838  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  UK
# 839  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  UK
# 840  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  UK
# 841  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  UK
#
#      TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0           2000     1700.0      NaN
# 1           2001     1850.0      NaN
# 2           2002     1940.0      NaN
# 3           2003     2060.0      NaN
# 4           2004     2180.0      NaN
# ..           ...        ...      ...
# 837         2015    31780.0      NaN
# 838         2016    32060.0      NaN
# 839         2017    32430.0      NaN
# 840         2018    32640.0      NaN
# 841         2019    32910.0      NaN
#
# [842 rows x 9 columns]

# %%
gdp_21 = gdp_table[gdp_table['TIME_PERIOD'] == 2021]

# %%
gdp_21 = gdp_21.sort_values(by='OBS_VALUE', ascending=False)

# %%
gdp_21.head()
# Out:
#                  DATAFLOW        LAST UPDATE freq           unit na_item geo  \
# 524  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  LU
# 436  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  IE
# 646  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  NO
# 108  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  CH
# 196  ESTAT:SDG_08_10(1.0)  07/04/22 23:00:00    A  CLV10_EUR_HAB    B1GQ  DK
#
#      TIME_PERIOD  OBS_VALUE OBS_FLAG
# 524         2021    86550.0      NaN
# 436         2021    70920.0      NaN
# 646         2021    70900.0      NaN
# 108         2021    62600.0        p
# 196         2021    50200.0      NaN

# %%
# GDP per capita for 2021 in Europe .................TABLE FOR SQL
gdp_21 = gdp_21[['geo', 'OBS_VALUE']]
gdp_21
# Out:
#            geo  OBS_VALUE
# 524         LU    86550.0
# 436         IE    70920.0
# 646         NO    70900.0
# 108         CH    62600.0
# 196         DK    50200.0
# 756         SE    44340.0
# 624         NL    41970.0
# 348         FI    37400.0
# 458         IS    36890.0
# 42          AT    36820.0
# 64          BE    35870.0
# 174         DE    35290.0
# 370         FR    32650.0
# 218       EA19    30850.0
# 306  EU27_2020    27800.0
# 480         IT    26700.0
# 130         CY    24920.0
# 284         ES    23510.0
# 602         MT    22030.0
# 778         SI    21260.0
# 152         CZ    17920.0
# 690         PT    17920.0
# 262         EL    17590.0
# 240         EE    16260.0
# 800         SK    15660.0
# 502         LT    14690.0
# 414         HU    13660.0
# 668         PL    13500.0
# 392         HR    13480.0
# 546         LV    12820.0
# 712         RO     9380.0
# 86          BG     6690.0
# 734         RS     5890.0

# %%
#Top 13 GDP Countries for sql
gdp_21_top13 = gdp_21.head(13)
gdp_21_top13
# Out:
#     geo  OBS_VALUE
# 524  LU    86550.0
# 436  IE    70920.0
# 646  NO    70900.0
# 108  CH    62600.0
# 196  DK    50200.0
# 756  SE    44340.0
# 624  NL    41970.0
# 348  FI    37400.0
# 458  IS    36890.0
# 42   AT    36820.0
# 64   BE    35870.0
# 174  DE    35290.0
# 370  FR    32650.0

# %%
# Creating a simple bar chart and 
plt.figure(figsize=(22,7))
plt.bar(gdp_21_top13['geo'], gdp_21_top13['OBS_VALUE'])
plt.title('Country vs. GDP per capita 2021', fontsize=20)
plt.xlabel('Country', fontsize=20)
plt.xticks(rotation=45)
plt.ylabel('GDP per capita', fontsize=20)



plt.show()

# %% [markdown]
# # Job vacancy statistics (jvs) EUROSTAT DATABASE

# %%
jvs_table= pd.read_csv('./data/jvs_a_rate_r2_1_Data.csv')

# %%
jvs_table
# Out:
#      TIME                                                GEO  \
# 0    2012                                            Belgium
# 1    2012                                        Netherlands
# 2    2012                                            Austria
# 3    2012                                             Norway
# 4    2012                                            Denmark
# ..    ...                                                ...
# 375  2021          European Union - 28 countries (2013-2020)
# 376  2021          European Union - 27 countries (2007-2013)
# 377  2021  Euro area (EA11-1999, EA12-2001, EA13-2007, EA...
# 378  2021                                             France
# 379  2021                                     United Kingdom
#
#                            NACE_R2 SIZECLAS            UNIT Value  \
# 0    Information and communication    Total  Annual average   4.4
# 1    Information and communication    Total  Annual average   3.1
# 2    Information and communication    Total  Annual average   2.7
# 3    Information and communication    Total  Annual average   3.7
# 4    Information and communication    Total  Annual average   2.0
# ..                             ...      ...             ...   ...
# 375  Information and communication    Total  Annual average     :
# 376  Information and communication    Total  Annual average     :
# 377  Information and communication    Total  Annual average     :
# 378  Information and communication    Total  Annual average     :
# 379  Information and communication    Total  Annual average     :
#
#     Flag and Footnotes
# 0                    b
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 375                NaN
# 376                NaN
# 377                NaN
# 378                NaN
# 379                NaN
#
# [380 rows x 7 columns]

# %%
jvs_table.dtypes
# Out:
# TIME                   int64
# GEO                   object
# NACE_R2               object
# SIZECLAS              object
# UNIT                  object
# Value                 object
# Flag and Footnotes    object
# dtype: object

# %%
jvs_table['GEO'] = jvs_table['GEO'].astype(str)
jvs_table.dtypes
# Out:
# TIME                   int64
# GEO                   object
# NACE_R2               object
# SIZECLAS              object
# UNIT                  object
# Value                 object
# Flag and Footnotes    object
# dtype: object

# %% [markdown]
# # Aditional Tables EUROSTAT DATABASE

# %%
part_empl_edu= pd.read_csv('./data/participation_of_aempl_education.csv')

# %%
part_empl_edu
# Out:
#                                DATAFLOW        LAST UPDATE freq unit emp_cont  \
# 0    ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
# 1    ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
# 2    ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
# 3    ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
# 4    ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
# ..                                  ...                ...  ...  ...      ...
# 382  ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
# 383  ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
# 384  ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
# 385  ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
# 386  ESTAT:TRNG_LFS_05$DEFAULTVIEW(1.0)  09/03/22 11:00:00    A   PC    TOTAL
#
#     sex     age geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0     T  Y18-64  AT         2011       17.6      NaN
# 1     T  Y18-64  AT         2012       18.5      NaN
# 2     T  Y18-64  AT         2013       18.2      NaN
# 3     T  Y18-64  AT         2014       18.4      NaN
# 4     T  Y18-64  AT         2015       18.4      NaN
# ..   ..     ...  ..          ...        ...      ...
# 382   T  Y18-64  UK         2015       20.7      NaN
# 383   T  Y18-64  UK         2016       19.5      NaN
# 384   T  Y18-64  UK         2017       19.2      NaN
# 385   T  Y18-64  UK         2018       19.5      NaN
# 386   T  Y18-64  UK         2019       19.8      NaN
#
# [387 rows x 11 columns]

# %%
part_inf_edu= pd.read_csv('./data/participation_informal_eustat.csv')

# %%
part_inf_edu
# Out:
#                                DATAFLOW        LAST UPDATE freq  training  \
# 0   ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
# 1   ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
# 2   ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
# 3   ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
# 4   ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
# ..                                  ...                ...  ...       ...
# 63  ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
# 64  ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
# 65  ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
# 66  ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
# 67  ESTAT:TRNG_AES_201$DEFAULTVIEW(1.0)  02/12/20 23:00:00    A       inf
#
#    learning     age unit geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0     TOTAL  Y25-64   PC  AL         2016       67.8      NaN
# 1     TOTAL  Y25-64   PC  AT         2007       75.7      NaN
# 2     TOTAL  Y25-64   PC  AT         2016       79.3      NaN
# 3     TOTAL  Y25-64   PC  BA         2016       74.7      NaN
# 4     TOTAL  Y25-64   PC  BE         2007       34.9      NaN
# ..      ...     ...  ...  ..          ...        ...      ...
# 63    TOTAL  Y25-64   PC  SK         2016       75.1      NaN
# 64    TOTAL  Y25-64   PC  TR         2007       30.5      NaN
# 65    TOTAL  Y25-64   PC  TR         2016       32.4      NaN
# 66    TOTAL  Y25-64   PC  UK         2007       53.7      NaN
# 67    TOTAL  Y25-64   PC  UK         2016       66.2        b
#
# [68 rows x 11 columns]

# %%
mean_annual_earning= pd.read_csv('./data/mean_annual_earnings.csv')

# %%
mean_annual_earning
# Out:
#                      DATAFLOW        LAST UPDATE freq    age indic_se  \
# 0    ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
# 1    ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
# 2    ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
# 3    ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
# 4    ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
# ..                        ...                ...  ...    ...      ...
# 115  ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
# 116  ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
# 117  ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
# 118  ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
# 119  ESTAT:EARN_SES18_27(1.0)  04/08/21 23:00:00    A  TOTAL      ERN
#
#      nace_r2 sex sizeclas unit geo  TIME_PERIOD  OBS_VALUE  OBS_FLAG
# 0    B-S_X_O   F     GE10  EUR  AL         2018       4626       NaN
# 1    B-S_X_O   F     GE10  EUR  AT         2018      39116       NaN
# 2    B-S_X_O   F     GE10  EUR  BE         2018      43684       NaN
# 3    B-S_X_O   F     GE10  EUR  BG         2018       7421       NaN
# 4    B-S_X_O   F     GE10  EUR  CH         2018      70672       NaN
# ..       ...  ..      ...  ...  ..          ...        ...       ...
# 115  B-S_X_O   T     GE10  EUR  SE         2018      43742       NaN
# 116  B-S_X_O   T     GE10  EUR  SI         2018      24669       NaN
# 117  B-S_X_O   T     GE10  EUR  SK         2018      15038       NaN
# 118  B-S_X_O   T     GE10  EUR  TR         2018       9191       NaN
# 119  B-S_X_O   T     GE10  EUR  UK         2018      40306       NaN
#
# [120 rows x 13 columns]

# %%
region_innovation= pd.read_csv('./data/REGION_INNOVATION.csv')
region_innovation
# Out:
#        TL Territory level and Typology REG_ID            Region  \
# 0       2          Large regions (TL2)   AT11        Burgenland
# 1       2          Large regions (TL2)   AT11        Burgenland
# 2       2          Large regions (TL2)   AT11        Burgenland
# 3       2          Large regions (TL2)   AT11        Burgenland
# 4       2          Large regions (TL2)   AT11        Burgenland
# ...    ..                          ...    ...               ...
# 11187   2          Large regions (TL2)   SI03  Eastern Slovenia
# 11188   2          Large regions (TL2)   SI04  Western Slovenia
# 11189   2          Large regions (TL2)   SI04  Western Slovenia
# 11190   2          Large regions (TL2)   SI04  Western Slovenia
# 11191   2          Large regions (TL2)   SI04  Western Slovenia
#
#                   VAR                                          Indicator  POS  \
# 0        KIS_EMP_T_SH  Share of employment in knowledge-intensive ser...  ALL
# 1           KIS_EMP_T         Employment in knowledge-intensive services  ALL
# 2        KIS_EMP_T_SH  Share of employment in knowledge-intensive ser...  ALL
# 3           KIS_EMP_T         Employment in knowledge-intensive services  ALL
# 4        KIS_EMP_T_SH  Share of employment in knowledge-intensive ser...  ALL
# ...               ...                                                ...  ...
# 11187       KIS_EMP_T         Employment in knowledge-intensive services  ALL
# 11188  HT_MG_EMP_T_SH  Share of employment in high-technology manufac...  ALL
# 11189    KIS_EMP_T_SH  Share of employment in knowledge-intensive ser...  ALL
# 11190     HT_MG_EMP_T        Employment in high-technology manufacturing  ALL
# 11191       KIS_EMP_T         Employment in knowledge-intensive services  ALL
#
#           Position  TIME  Year  Unit Code  Unit  PowerCode Code PowerCode  \
# 0      All regions  2008  2008        NaN   NaN               0     Units
# 1      All regions  2008  2008        NaN   NaN               0     Units
# 2      All regions  2009  2009        NaN   NaN               0     Units
# 3      All regions  2009  2009        NaN   NaN               0     Units
# 4      All regions  2010  2010        NaN   NaN               0     Units
# ...            ...   ...   ...        ...   ...             ...       ...
# 11187  All regions  2019  2019        NaN   NaN               0     Units
# 11188  All regions  2019  2019        NaN   NaN               0     Units
# 11189  All regions  2019  2019        NaN   NaN               0     Units
# 11190  All regions  2019  2019        NaN   NaN               0     Units
# 11191  All regions  2019  2019        NaN   NaN               0     Units
#
#        Reference Period Code  Reference Period      Value Flag Codes  Flags
# 0                        NaN               NaN      34.08          B  Break
# 1                        NaN               NaN   45500.00          B  Break
# 2                        NaN               NaN      34.96        NaN    NaN
# 3                        NaN               NaN   46600.00        NaN    NaN
# 4                        NaN               NaN      37.30        NaN    NaN
# ...                      ...               ...        ...        ...    ...
# 11187                    NaN               NaN  159500.00        NaN    NaN
# 11188                    NaN               NaN       1.65        NaN    NaN
# 11189                    NaN               NaN      40.46        NaN    NaN
# 11190                    NaN               NaN    7800.00        NaN    NaN
# 11191                    NaN               NaN  190800.00        NaN    NaN
#
# [11192 rows x 19 columns]

# %%
government_expenditure= pd.read_csv('./data/government_expenditure.csv')
government_expenditure
# Out:
#           Countries  Date  Expenditure ($M)  Education Expenditure (%Bud.)  \
# 0     United States  2020           9495390                          0.134
# 1    United Kingdom  2020           1333690                          0.133
# 2           Germany  2020           1955596                          0.112
# 3            France  2020           1621459                          0.097
# 4             Japan  2019           1916314                          0.084
# ..              ...   ...               ...                            ...
# 186           Samoa  2020               262                          0.162
# 187           Yemen  2020              2222                          0.125
# 188    South Africa  2020            120938                          0.195
# 189          Zambia  2020              6185                          0.124
# 190        Zimbabwe  2019             24840                          0.190
#
#      Gov. Health Exp. (%Bud.)  Defence Expenditure (%Bud.)  \
# 0                       0.226                        0.079
# 1                       0.187                        0.042
# 2                       0.199                        0.030
# 3                       0.155                        0.032
# 4                       0.236                        0.025
# ..                        ...                          ...
# 186                     0.116                          NaN
# 187                     0.000                        0.143
# 188                     0.133                        0.026
# 189                     0.069                        0.048
# 190                     0.152                        0.021
#
#      Expenditure (%GDP)    Ch.
# 0                 0.455   9.64
# 1                 0.491   8.01
# 2                 0.508   5.60
# 3                 0.616   6.00
# 4                 0.373   0.32
# ..                  ...    ...
# 186               0.322  -0.80
# 187               0.118  -1.13
# 188               0.360   4.27
# 189               0.319   2.12
# 190               0.156 -16.32
#
# [191 rows x 8 columns]

# %%
# Reseting all indexes

comments = comments.reset_index()
locations = locations.reset_index()
badges = badges.reset_index()
schools = schools.reset_index()
courses = courses.reset_index()
itc_services =itc_services.reset_index()
gdp_table = gdp_table.reset_index()
jvs_table =jvs_table.reset_index()
part_empl_edu = part_empl_edu.reset_index()
mean_annual_earning = mean_annual_earning.reset_index()
region_innovation = region_innovation.reset_index()
government_expenditure =government_expenditure.reset_index()

# %% [markdown]
# ## Sending dataframes to MySQL

# %%
import mysql.connector
import getpass

saved_password = getpass.getpass()
cnx = mysql.connector.connect(user = 'root', # Specify your user 
                              password = saved_password, 
                              host ='localhost', 
                              database = 'sakila',
                              auth_plugin='mysql_native_password')
# Out:
# ········

# %%
cnx.is_connected()
if cnx.is_connected():
    print("Connection open")
    # do stuff you need to the database
else:
    print("Connection is not successfully open")
# Out:
# Connection open

# %%
cursor = cnx.cursor()

#Create database

def sql_db(db_name):
    query = f"CREATE DATABASE {db_name}"
    print(query)
    use_db = f"USE {db_name}"
    print(use_db)
    cursor.execute(query)
    cursor.execute(use_db)
    return db_name 

#Execute the full process of a query

def sql_action():
    query = input('Please write your query...')
    #cursor.execute(query,multi=True)
    results = cursor.fetchall()
    results_df = pd.DataFrame(results)
    return "Action completed" 

#Finalize SQL process

def sql_close_connection():
    return cnx.commit(), cursor.close(), cnx.close()

# %%
# Creating database - create it as string

db = sql_db("sql_project")
# Out:
# CREATE DATABASE sql_project
# USE sql_project

# %%
# Alchemy setup 

from sqlalchemy import create_engine
import pymysql # run pip install pymysql (pip3 for Mac) 

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw=saved_password,
                               db=db))

# %%
# Alchemy insert values - having problems when looped
badges.to_sql('badges', con = engine, if_exists = 'replace', chunksize = 1000)
locations.to_sql('locations', con = engine, if_exists = 'replace', chunksize = 1000)
courses.to_sql('courses', con = engine, if_exists = 'replace', chunksize = 1000)
schools.to_sql('schools', con = engine, if_exists = 'replace', chunksize = 1000)
comments.to_sql('comments', con = engine, if_exists = 'replace', chunksize = 1000)
itc_services.to_sql('itc_services', con = engine, if_exists = 'replace', chunksize = 1000)
itc_services.to_sql('itc_gdp', con = engine, if_exists = 'replace', chunksize = 1000)
gdp_table.to_sql('gdp_table', con = engine, if_exists = 'replace', chunksize = 1000)
jvs_table.to_sql('jvs_table', con = engine, if_exists = 'replace', chunksize = 1000)
part_empl_edu.to_sql('part_empl_edu', con = engine, if_exists = 'replace', chunksize = 1000)
mean_annual_earning.to_sql('mean_annual_earning', con = engine, if_exists = 'replace', chunksize = 1000)
region_innovation.to_sql('region_innovation', con = engine, if_exists = 'replace', chunksize = 1000)
government_expenditure.to_sql('government_expenditure', con = engine, if_exists = 'replace', chunksize = 1000)

# %%
# Setting primary KEYs with pandas default indexes - locations table has already an id so we would need to rename based on another keyword or keep it as level_0
cursor.execute("ALTER TABLE comments ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE schools ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE locations ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE courses ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE badges ADD PRIMARY KEY (level_0)")

cursor.execute("ALTER TABLE itc_services ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE itc_gdp ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE gdp_table ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE jvs_table ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE part_empl_edu ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE mean_annual_earning ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE region_innovation ADD PRIMARY KEY (level_0)")
cursor.execute("ALTER TABLE government_expenditure ADD PRIMARY KEY (level_0)")

cursor.fetchall()
# Out:
# []

# %%
# Setting foreign KEYs for switchup tables
#cursor.execute("ALTER TABLE comments ADD FOREIGN KEY (school VARCHAR(258)) REFERENCES schools(school);")
#cursor.execute("ALTER TABLE schools ADD FOREIGN KEY (school VARCHAR(258)) REFERENCES comments(school);")
#cursor.execute("ALTER TABLE locations ADD FOREIGN KEY (school_id BIGINT) REFERENCES schools(school_id);")
#cursor.execute("ALTER TABLE courses ADD FOREIGN KEY (school_id BIGINT) REFERENCES schools(school_id);")
#cursor.execute("ALTER TABLE badges ADD FOREIGN KEY (school_id BIGINT) REFERENCES schools(school_id);")

#cursor.execute("ALTER TABLE itc_services ADD FOREIGN KEY (GEO VARCHAR(258)) REFERENCES locations(country_name);")
#cursor.execute("ALTER TABLE gdp_table ADD FOREIGN KEY (geo VARCHAR(258)) REFERENCES locations(country_abbrev);")
#cursor.execute("ALTER TABLE jvs_table ADD FOREIGN KEY (GEO VARCHAR(258)) REFERENCES locations(country_name);")
#cursor.execute("ALTER TABLE part_empl_edu ADD FOREIGN KEY (geo VARCHAR(258)) REFERENCES locations(country_abbrev);")
#cursor.execute("ALTER TABLE mean_annual_earning ADD FOREIGN KEY (geo VARCHAR(258)) REFERENCES locations(country_abbrev);")
# cursor.execute("ALTER TABLE region_innovation ADD PRIMARY KEY (level_0)")
#cursor.execute("ALTER TABLE government_expenditure ADD FOREIGN KEY (GEO VARCHAR(258)) REFERENCES locations(country_name);")

#cursor.fetchall()
